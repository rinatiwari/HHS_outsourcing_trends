# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import pandas_profiling
import numpy as np
import requests
import time
import pprint
import json
import os

# %%
# Save path to data set in a variable
#data_file = "Data_to_Clean/all_contracts_prime_transactions_2019_1.csv"

# %%
# Importing slimmed down annual files
df_2019_1 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2019_1.csv")
df_2019_2 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2019_2.csv")
df_2018_1 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2018_1.csv")
df_2018_2 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2018_2.csv")
df_2017_1 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2017_1.csv")
df_2017_2 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2017_2.csv")
df_2016_1 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2016_1.csv")
df_2016_2 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2016_2.csv")
df_2015_1 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2015_1.csv")
df_2015_2 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2015_2.csv")
df_2014_1 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2014_1.csv")
df_2014_2 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2014_2.csv")
df_2013_1 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2013_1.csv")
df_2013_2 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2013_2.csv")
df_2012_1 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2012_1.csv")
df_2012_2 = pd.read_csv("Data_to_Clean/all_contracts_prime_transactions_2012_2.csv")

df_2019 = df_2019_1
df_2019 = df_2019.append(df_2019_2)
df_2018 = df_2018_1
df_2018 = df_2018.append(df_2018_2)
df_2017 = df_2017_1
df_2017 = df_2017.append(df_2017_2)
df_2016 = df_2016_1
df_2016 = df_2016.append(df_2016_2)
df_2015 = df_2015_1
df_2015 = df_2015.append(df_2015_2)
df_2014 = df_2014_1
df_2014 = df_2014.append(df_2014_2)
df_2013 = df_2013_1
df_2013 = df_2013.append(df_2013_2)
df_2012 = df_2012_1
df_2012 = df_2012.append(df_2012_2)
# Out:
# C:\Users\rinat\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (21,30,39,55,56,87,88,115,116,159,160) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\rinat\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (21,30,39,55,56,73,87,88,115,116,159,160) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\rinat\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3,21,30,39,87,88,159,160) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\rinat\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3,21,30,39,55,56,63,87,88,115,116,159,160) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\rinat\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3,21,30,39,73,159,160) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\rinat\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3,21,30,39,55,56,159,160) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\rinat\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3,26,30,55,56,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\rinat\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3,21,26,30,40,55,56,115,159,160) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\rinat\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3,30,159,160,266,268,270,272,274) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\rinat\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3,21,30,40,45,159,160,266,268,270,272,274) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\rinat\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (21,30,55,56,115,159,160,266,268,270,272,274) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\rinat\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3,8,26,30,32,43,49,55,56,63,81,82,115,150,266,268,270,272,274) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\rinat\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (3,8,21,26,30,32,49,53,54,55,56,63,73,97,98,115,116,159,160,266,268,270,272,274) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Print the amount of data we have for each year
print(f"Number of rows in 2019 data: {len(df_2019['award_id_piid'])}")
print(f"Number of rows in 2018 data: {len(df_2018['award_id_piid'])}")
print(f"Number of rows in 2017 data: {len(df_2017['award_id_piid'])}")
print(f"Number of rows in 2016 data: {len(df_2016['award_id_piid'])}")
print(f"Number of rows in 2015 data: {len(df_2015['award_id_piid'])}")
print(f"Number of rows in 2014 data: {len(df_2014['award_id_piid'])}")
print(f"Number of rows in 2013 data: {len(df_2013['award_id_piid'])}")
print(f"Number of rows in 2012 data: {len(df_2012['award_id_piid'])}")
# Out:
# Number of rows in 2019 data: 67396
# Number of rows in 2018 data: 76785
# Number of rows in 2017 data: 82985
# Number of rows in 2016 data: 80696
# Number of rows in 2015 data: 84112
# Number of rows in 2014 data: 87627
# Number of rows in 2013 data: 82889
# Number of rows in 2012 data: 81966

# %%
# Print the number of columns we currently have for each year
print(f"Number of columns in 2019 data: {len(df_2019.columns)}")
print(f"Number of columns in 2018 data: {len(df_2018.columns)}")
print(f"Number of columns in 2017 data: {len(df_2017.columns)}")
print(f"Number of columns in 2016 data: {len(df_2016.columns)}")
print(f"Number of columns in 2015 data: {len(df_2015.columns)}")
print(f"Number of columns in 2014 data: {len(df_2014.columns)}")
print(f"Number of columns in 2013 data: {len(df_2013.columns)}")
print(f"Number of columns in 2012 data: {len(df_2012.columns)}")
# Out:
# Number of columns in 2019 data: 277
# Number of columns in 2018 data: 277
# Number of columns in 2017 data: 277
# Number of columns in 2016 data: 277
# Number of columns in 2015 data: 277
# Number of columns in 2014 data: 277
# Number of columns in 2013 data: 277
# Number of columns in 2012 data: 277

# %%
# Show all of the columns within the spreadsheets
for column in df_2019.columns:
    print(column)
# Out:
# contract_transaction_unique_key
# contract_award_unique_key
# award_id_piid
# modification_number
# transaction_number
# parent_award_agency_id
# parent_award_agency_name
# parent_award_id
# parent_award_modification_number
# federal_action_obligation
# total_dollars_obligated
# base_and_exercised_options_value
# current_total_value_of_award
# base_and_all_options_value
# potential_total_value_of_award
# action_date
# action_date_fiscal_year
# period_of_performance_start_date
# period_of_performance_current_end_date
# period_of_performance_potential_end_date
# ordering_period_end_date
# solicitation_date
# awarding_agency_code
# awarding_agency_name
# awarding_sub_agency_code
# awarding_sub_agency_name
# awarding_office_code
# awarding_office_name
# funding_agency_code
# funding_agency_name
# funding_sub_agency_code
# funding_sub_agency_name
# funding_office_code
# funding_office_name
# treasury_accounts_funding_this_award
# federal_accounts_funding_this_award
# foreign_funding
# foreign_funding_description
# sam_exception
# sam_exception_description
# recipient_duns
# recipient_name
# recipient_doing_business_as_name
# cage_code
# recipient_parent_name
# recipient_parent_duns
# recipient_country_code
# recipient_country_name
# recipient_address_line_1
# recipient_address_line_2
# recipient_city_name
# recipient_state_code
# recipient_state_name
# recipient_zip_4_code
# recipient_congressional_district
# recipient_phone_number
# recipient_fax_number
# primary_place_of_performance_country_code
# primary_place_of_performance_country_name
# primary_place_of_performance_city_name
# primary_place_of_performance_county_name
# primary_place_of_performance_state_code
# primary_place_of_performance_state_name
# primary_place_of_performance_zip_4
# primary_place_of_performance_congressional_district
# award_or_idv_flag
# award_type_code
# award_type
# idv_type_code
# idv_type
# multiple_or_single_award_idv_code
# multiple_or_single_award_idv
# type_of_idc_code
# type_of_idc
# type_of_contract_pricing_code
# type_of_contract_pricing
# award_description
# action_type_code
# action_type
# solicitation_identifier
# number_of_actions
# inherently_governmental_functions
# inherently_governmental_functions_description
# product_or_service_code
# product_or_service_code_description
# contract_bundling_code
# contract_bundling
# dod_claimant_program_code
# dod_claimant_program_description
# naics_code
# naics_description
# recovered_materials_sustainability_code
# recovered_materials_sustainability
# domestic_or_foreign_entity_code
# domestic_or_foreign_entity
# dod_acquisition_program_code
# dod_acquisition_program_description
# information_technology_commercial_item_category_code
# information_technology_commercial_item_category
# epa_designated_product_code
# epa_designated_product
# country_of_product_or_service_origin_code
# country_of_product_or_service_origin
# place_of_manufacture_code
# place_of_manufacture
# subcontracting_plan_code
# subcontracting_plan
# extent_competed_code
# extent_competed
# solicitation_procedures_code
# solicitation_procedures
# type_of_set_aside_code
# type_of_set_aside
# evaluated_preference_code
# evaluated_preference
# research_code
# research
# fair_opportunity_limited_sources_code
# fair_opportunity_limited_sources
# other_than_full_and_open_competition_code
# other_than_full_and_open_competition
# number_of_offers_received
# commercial_item_acquisition_procedures_code
# commercial_item_acquisition_procedures
# small_business_competitiveness_demonstration_program
# commercial_item_test_program_code
# commercial_item_test_program
# a76_fair_act_action_code
# a76_fair_act_action
# fed_biz_opps_code
# fed_biz_opps
# local_area_set_aside_code
# local_area_set_aside
# price_evaluation_adjustment_preference_percent_difference
# clinger_cohen_act_planning_code
# clinger_cohen_act_planning
# materials_supplies_articles_equipment_code
# materials_supplies_articles_equipment
# labor_standards_code
# labor_standards
# construction_wage_rate_requirements_code
# construction_wage_rate_requirements
# interagency_contracting_authority_code
# interagency_contracting_authority
# other_statutory_authority
# program_acronym
# parent_award_type_code
# parent_award_type
# parent_award_single_or_multiple_code
# parent_award_single_or_multiple
# major_program
# national_interest_action_code
# national_interest_action
# cost_or_pricing_data_code
# cost_or_pricing_data
# cost_accounting_standards_clause_code
# cost_accounting_standards_clause
# gfe_gfp_code
# gfe_gfp
# sea_transportation_code
# sea_transportation
# undefinitized_action_code
# undefinitized_action
# consolidated_contract_code
# consolidated_contract
# performance_based_service_acquisition_code
# performance_based_service_acquisition
# multi_year_contract_code
# multi_year_contract
# contract_financing_code
# contract_financing
# purchase_card_as_payment_method_code
# purchase_card_as_payment_method
# contingency_humanitarian_or_peacekeeping_operation_code
# contingency_humanitarian_or_peacekeeping_operation
# alaskan_native_owned_corporation_or_firm
# american_indian_owned_business
# indian_tribe_federally_recognized
# native_hawaiian_owned_business
# tribally_owned_business
# veteran_owned_business
# service_disabled_veteran_owned_business
# woman_owned_business
# women_owned_small_business
# economically_disadvantaged_women_owned_small_business
# joint_venture_women_owned_small_business
# joint_venture_economic_disadvantaged_women_owned_small_bus
# minority_owned_business
# subcontinent_asian_asian_indian_american_owned_business
# asian_pacific_american_owned_business
# black_american_owned_business
# hispanic_american_owned_business
# native_american_owned_business
# other_minority_owned_business
# contracting_officers_determination_of_business_size
# contracting_officers_determination_of_business_size_code
# emerging_small_business
# community_developed_corporation_owned_firm
# labor_surplus_area_firm
# us_federal_government
# federally_funded_research_and_development_corp
# federal_agency
# us_state_government
# us_local_government
# city_local_government
# county_local_government
# inter_municipal_local_government
# local_government_owned
# municipality_local_government
# school_district_local_government
# township_local_government
# us_tribal_government
# foreign_government
# organizational_type
# corporate_entity_not_tax_exempt
# corporate_entity_tax_exempt
# partnership_or_limited_liability_partnership
# sole_proprietorship
# small_agricultural_cooperative
# international_organization
# us_government_entity
# community_development_corporation
# domestic_shelter
# educational_institution
# foundation
# hospital_flag
# manufacturer_of_goods
# veterinary_hospital
# hispanic_servicing_institution
# receives_contracts
# receives_grants
# receives_contracts_and_grants
# airport_authority
# council_of_governments
# housing_authorities_public_tribal
# interstate_entity
# planning_commission
# port_authority
# transit_authority
# subchapter_scorporation
# limited_liability_corporation
# foreign_owned_and_located
# for_profit_organization
# nonprofit_organization
# other_not_for_profit_organization
# the_ability_one_program
# number_of_employees
# annual_revenue
# private_university_or_college
# state_controlled_institution_of_higher_learning
# 1862_land_grant_college
# 1890_land_grant_college
# 1994_land_grant_college
# minority_institution
# historically_black_college
# tribal_college
# alaskan_native_servicing_institution
# native_hawaiian_servicing_institution
# school_of_forestry
# veterinary_college
# dot_certified_disadvantage
# self_certified_small_disadvantaged_business
# small_disadvantaged_business
# c8a_program_participant
# historically_underutilized_business_zone_hubzone_firm
# sba_certified_8a_joint_venture
# highly_compensated_officer_1_name
# highly_compensated_officer_1_amount
# highly_compensated_officer_2_name
# highly_compensated_officer_2_amount
# highly_compensated_officer_3_name
# highly_compensated_officer_3_amount
# highly_compensated_officer_4_name
# highly_compensated_officer_4_amount
# highly_compensated_officer_5_name
# highly_compensated_officer_5_amount
# last_modified_date

# %%
# Take out all of the rows we know will not be needed at this time
columns_to_drop = ['parent_award_agency_id','parent_award_id','potential_total_value_of_award','base_and_exercised_options_value',
                              'current_total_value_of_award','base_and_all_options_value','ordering_period_end_date','solicitation_date',
                              'awarding_agency_code','awarding_sub_agency_code','awarding_office_code','funding_agency_code',
                              'funding_sub_agency_code','funding_office_code','sam_exception','sam_exception_description','recipient_duns','recipient_doing_business_as_name',
                              'cage_code','recipient_parent_duns','recipient_country_code','recipient_address_line_2','recipient_state_code','domestic_shelter',
                              'community_development_corporation', 'us_government_entity','international_organization','small_agricultural_cooperative',
                              'sole_proprietorship','partnership_or_limited_liability_partnership','corporate_entity_tax_exempt','corporate_entity_not_tax_exempt',
                              'us_tribal_government','township_local_government','school_district_local_government','municipality_local_government',
                              'local_government_owned','inter_municipal_local_government','county_local_government','city_local_government',
                              'us_local_government','us_state_government','federally_funded_research_and_development_corp','us_federal_government',
                              'labor_surplus_area_firm','organizational_type','foreign_government','indian_tribe_federally_recognized','native_hawaiian_owned_business',
                               'contingency_humanitarian_or_peacekeeping_operation_code','purchase_card_as_payment_method_code',
                               'contract_financing','contract_financing_code','multi_year_contract_code','performance_based_service_acquisition',
                               'performance_based_service_acquisition_code','consolidated_contract','consolidated_contract_code','undefinitized_action',
                               'undefinitized_action_code','sea_transportation','sea_transportation_code','gfe_gfp','gfe_gfp_code','cost_accounting_standards_clause',
                               'cost_accounting_standards_clause_code','cost_or_pricing_data','cost_or_pricing_data_code','national_interest_action_code',
                               'parent_award_single_or_multiple_code','parent_award_type','parent_award_type_code','program_acronym',
                               'other_statutory_authority','interagency_contracting_authority','interagency_contracting_authority_code',
                               'construction_wage_rate_requirements_code','labor_standards_code','materials_supplies_articles_equipment',
                               'materials_supplies_articles_equipment_code','clinger_cohen_act_planning','clinger_cohen_act_planning_code',
                               'price_evaluation_adjustment_preference_percent_difference','local_area_set_aside','local_area_set_aside_code',
                               'fed_biz_opps_code','a76_fair_act_action_code','commercial_item_test_program','commercial_item_test_program_code','commercial_item_acquisition_procedures',
                               'commercial_item_acquisition_procedures_code','fair_opportunity_limited_sources_code','research_code','evaluated_preference',
                               'evaluated_preference_code','type_of_set_aside_code','solicitation_procedures_code','extent_competed_code',
                               'subcontracting_plan_code','place_of_manufacture_code','country_of_product_or_service_origin_code',
                               'epa_designated_product','epa_designated_product_code','information_technology_commercial_item_category',
                               'information_technology_commercial_item_category_code','dod_acquisition_program_description','dod_acquisition_program_code',
                               'domestic_or_foreign_entity_code','recovered_materials_sustainability_code','naics_code',
                               'dod_claimant_program_description','dod_claimant_program_code','contract_bundling','contract_bundling_code',
                               'inherently_governmental_functions_description','inherently_governmental_functions','solicitation_identifier',
                               'action_type_code','type_of_contract_pricing_code','type_of_idc','type_of_idc_code','multiple_or_single_award_idv',
                               'multiple_or_single_award_idv_code','idv_type','idv_type_code','award_type_code','award_or_idv_flag',
                               'primary_place_of_performance_congressional_district','primary_place_of_performance_zip_4','primary_place_of_performance_state_code',
                               'primary_place_of_performance_county_name','primary_place_of_performance_country_code',
                               'recipient_fax_number','recipient_phone_number','recipient_congressional_district','recipient_zip_4_code',
                               'foreign_funding_description','foreign_funding','federal_accounts_funding_this_award','treasury_accounts_funding_this_award',
                               'solicitation_date','ordering_period_end_date','period_of_performance_potential_end_date','action_date','parent_award_modification_number',
                               'transaction_number','highly_compensated_officer_5_amount','highly_compensated_officer_5_name',
                             'highly_compensated_officer_4_amount','highly_compensated_officer_4_name',
                             'highly_compensated_officer_3_amount','highly_compensated_officer_3_name',
                             'highly_compensated_officer_2_amount','highly_compensated_officer_2_name',
                             'highly_compensated_officer_1_amount','highly_compensated_officer_1_name',
                             'last_modified_date','veterinary_college','school_of_forestry','native_hawaiian_servicing_institution',
                             'alaskan_native_servicing_institution','tribal_college','historically_black_college','minority_institution',
                             '1994_land_grant_college','1890_land_grant_college','1862_land_grant_college','1862_land_grant_college','state_controlled_institution_of_higher_learning',
                             'private_university_or_college','annual_revenue','number_of_employees','the_ability_one_program','other_not_for_profit_organization',
                             'nonprofit_organization','limited_liability_corporation','subchapter_scorporation','transit_authority','port_authority',
                             'planning_commission','interstate_entity','housing_authorities_public_tribal','council_of_governments',
                             'airport_authority','receives_contracts_and_grants','receives_grants','receives_contracts',
                             'hispanic_servicing_institution','veterinary_hospital','manufacturer_of_goods','hospital_flag','foundation','educational_institution']
df_2019_clean = df_2019.drop(columns_to_drop, axis=1)
df_2018_clean = df_2018.drop(columns_to_drop, axis=1)
df_2017_clean = df_2017.drop(columns_to_drop, axis=1)
df_2016_clean = df_2016.drop(columns_to_drop, axis=1)
df_2015_clean = df_2015.drop(columns_to_drop, axis=1)
df_2014_clean = df_2014.drop(columns_to_drop, axis=1)
df_2013_clean = df_2013.drop(columns_to_drop, axis=1)
df_2012_clean = df_2012.drop(columns_to_drop, axis=1)

# %%
# Show the columns that we dropped
for column in columns_to_drop:
    print(column)
# Out:
# parent_award_agency_id
# parent_award_id
# potential_total_value_of_award
# base_and_exercised_options_value
# current_total_value_of_award
# base_and_all_options_value
# ordering_period_end_date
# solicitation_date
# awarding_agency_code
# awarding_sub_agency_code
# awarding_office_code
# funding_agency_code
# funding_sub_agency_code
# funding_office_code
# sam_exception
# sam_exception_description
# recipient_duns
# recipient_doing_business_as_name
# cage_code
# recipient_parent_duns
# recipient_country_code
# recipient_address_line_2
# recipient_state_code
# domestic_shelter
# community_development_corporation
# us_government_entity
# international_organization
# small_agricultural_cooperative
# sole_proprietorship
# partnership_or_limited_liability_partnership
# corporate_entity_tax_exempt
# corporate_entity_not_tax_exempt
# us_tribal_government
# township_local_government
# school_district_local_government
# municipality_local_government
# local_government_owned
# inter_municipal_local_government
# county_local_government
# city_local_government
# us_local_government
# us_state_government
# federally_funded_research_and_development_corp
# us_federal_government
# labor_surplus_area_firm
# organizational_type
# foreign_government
# indian_tribe_federally_recognized
# native_hawaiian_owned_business
# contingency_humanitarian_or_peacekeeping_operation_code
# purchase_card_as_payment_method_code
# contract_financing
# contract_financing_code
# multi_year_contract_code
# performance_based_service_acquisition
# performance_based_service_acquisition_code
# consolidated_contract
# consolidated_contract_code
# undefinitized_action
# undefinitized_action_code
# sea_transportation
# sea_transportation_code
# gfe_gfp
# gfe_gfp_code
# cost_accounting_standards_clause
# cost_accounting_standards_clause_code
# cost_or_pricing_data
# cost_or_pricing_data_code
# national_interest_action_code
# parent_award_single_or_multiple_code
# parent_award_type
# parent_award_type_code
# program_acronym
# other_statutory_authority
# interagency_contracting_authority
# interagency_contracting_authority_code
# construction_wage_rate_requirements_code
# labor_standards_code
# materials_supplies_articles_equipment
# materials_supplies_articles_equipment_code
# clinger_cohen_act_planning
# clinger_cohen_act_planning_code
# price_evaluation_adjustment_preference_percent_difference
# local_area_set_aside
# local_area_set_aside_code
# fed_biz_opps_code
# a76_fair_act_action_code
# commercial_item_test_program
# commercial_item_test_program_code
# commercial_item_acquisition_procedures
# commercial_item_acquisition_procedures_code
# fair_opportunity_limited_sources_code
# research_code
# evaluated_preference
# evaluated_preference_code
# type_of_set_aside_code
# solicitation_procedures_code
# extent_competed_code
# subcontracting_plan_code
# place_of_manufacture_code
# country_of_product_or_service_origin_code
# epa_designated_product
# epa_designated_product_code
# information_technology_commercial_item_category
# information_technology_commercial_item_category_code
# dod_acquisition_program_description
# dod_acquisition_program_code
# domestic_or_foreign_entity_code
# recovered_materials_sustainability_code
# naics_code
# dod_claimant_program_description
# dod_claimant_program_code
# contract_bundling
# contract_bundling_code
# inherently_governmental_functions_description
# inherently_governmental_functions
# solicitation_identifier
# action_type_code
# type_of_contract_pricing_code
# type_of_idc
# type_of_idc_code
# multiple_or_single_award_idv
# multiple_or_single_award_idv_code
# idv_type
# idv_type_code
# award_type_code
# award_or_idv_flag
# primary_place_of_performance_congressional_district
# primary_place_of_performance_zip_4
# primary_place_of_performance_state_code
# primary_place_of_performance_county_name
# primary_place_of_performance_country_code
# recipient_fax_number
# recipient_phone_number
# recipient_congressional_district
# recipient_zip_4_code
# foreign_funding_description
# foreign_funding
# federal_accounts_funding_this_award
# treasury_accounts_funding_this_award
# solicitation_date
# ordering_period_end_date
# period_of_performance_potential_end_date
# action_date
# parent_award_modification_number
# transaction_number
# highly_compensated_officer_5_amount
# highly_compensated_officer_5_name
# highly_compensated_officer_4_amount
# highly_compensated_officer_4_name
# highly_compensated_officer_3_amount
# highly_compensated_officer_3_name
# highly_compensated_officer_2_amount
# highly_compensated_officer_2_name
# highly_compensated_officer_1_amount
# highly_compensated_officer_1_name
# last_modified_date
# veterinary_college
# school_of_forestry
# native_hawaiian_servicing_institution
# alaskan_native_servicing_institution
# tribal_college
# historically_black_college
# minority_institution
# 1994_land_grant_college
# 1890_land_grant_college
# 1862_land_grant_college
# 1862_land_grant_college
# state_controlled_institution_of_higher_learning
# private_university_or_college
# annual_revenue
# number_of_employees
# the_ability_one_program
# other_not_for_profit_organization
# nonprofit_organization
# limited_liability_corporation
# subchapter_scorporation
# transit_authority
# port_authority
# planning_commission
# interstate_entity
# housing_authorities_public_tribal
# council_of_governments
# airport_authority
# receives_contracts_and_grants
# receives_grants
# receives_contracts
# hispanic_servicing_institution
# veterinary_hospital
# manufacturer_of_goods
# hospital_flag
# foundation
# educational_institution

# %%
# Ensure that each dataframe only has data for a single year
print(f"2019 dataframe has data for: {df_2019_clean['action_date_fiscal_year'].unique()}")
print(f"2018 dataframe has data for: {df_2018_clean['action_date_fiscal_year'].unique()}")
print(f"2017 dataframe has data for: {df_2017_clean['action_date_fiscal_year'].unique()}")
print(f"2016 dataframe has data for: {df_2016_clean['action_date_fiscal_year'].unique()}")
print(f"2015 dataframe has data for: {df_2015_clean['action_date_fiscal_year'].unique()}")
print(f"2014 dataframe has data for: {df_2014_clean['action_date_fiscal_year'].unique()}")
print(f"2013 dataframe has data for: {df_2013_clean['action_date_fiscal_year'].unique()}")
print(f"2012 dataframe has data for: {df_2012_clean['action_date_fiscal_year'].unique()}")
# Out:
# 2019 dataframe has data for: [2019]
# 2018 dataframe has data for: [2018]
# 2017 dataframe has data for: [2017]
# 2016 dataframe has data for: [2016]
# 2015 dataframe has data for: [2015]
# 2014 dataframe has data for: [2014]
# 2013 dataframe has data for: [2013]
# 2012 dataframe has data for: [2012]

# %%
# Combine all years into a single dataframe
total_cleaned_data = df_2019_clean
total_cleaned_data = total_cleaned_data.append(df_2018_clean)
total_cleaned_data = total_cleaned_data.append(df_2017_clean)
total_cleaned_data = total_cleaned_data.append(df_2016_clean)
total_cleaned_data = total_cleaned_data.append(df_2015_clean)
total_cleaned_data = total_cleaned_data.append(df_2014_clean)
total_cleaned_data = total_cleaned_data.append(df_2013_clean)
total_cleaned_data = total_cleaned_data.append(df_2012_clean)

# %%
# Show the amount of data we have for each column
total_cleaned_data.count()
# Out:
# contract_transaction_unique_key                          644456
# contract_award_unique_key                                644456
# award_id_piid                                            644456
# modification_number                                      644456
# parent_award_agency_name                                 387899
#                                                           ...
# self_certified_small_disadvantaged_business              644456
# small_disadvantaged_business                             644456
# c8a_program_participant                                  644456
# historically_underutilized_business_zone_hubzone_firm    644456
# sba_certified_8a_joint_venture                           644456
# Length: 87, dtype: int64

# %%
# Export final dataframe to CSV
total_cleaned_data.to_csv("Annual_HSS_Data_Cleaned_no2011.csv", index=False)

# %%
#Import and Read Cleaned 
data_file = "Annual_HSS_Data_Cleaned_no2011.csv"

clean_data_df= pd.read_csv(data_file, encoding = 'iso-8859-1', low_memory=False)

#clean_data_df= pd.read_csv("Annual_HSS_Data_cleaned.csv")

# %%
#exploring data using pandas profiling

#pandas_profiling.ProfileReport(clean_data_df)

# %%
sort_data_df = clean_data_df[[
                                "contract_award_unique_key",
                                "action_date_fiscal_year",
                                "awarding_sub_agency_name",
                                "awarding_office_name",
                                "recipient_parent_name",
                                 "federal_action_obligation"]]
                           
        
sort_data_df.head(100)
# Out:
#                          contract_award_unique_key  action_date_fiscal_year  \
# 0       CONT_AWD_75D30118C01909_7523_-NONE-_-NONE-                     2019
# 1       CONT_AWD_75D30118C02052_7523_-NONE-_-NONE-                     2019
# 2    CONT_AWD_HHSD200201692404C_7523_-NONE-_-NONE-                     2019
# 3    CONT_AWD_HHSD200201692405C_7523_-NONE-_-NONE-                     2019
# 4    CONT_AWD_HHSD200201692406C_7523_-NONE-_-NONE-                     2019
# ..                                             ...                      ...
# 95   CONT_AWD_HHSI241201800073P_7527_-NONE-_-NONE-                     2019
# 96   CONT_AWD_HHSI245201700099M_7527_-NONE-_-NONE-                     2019
# 97  CONT_AWD_75FCMC18F0001_7530_75FCMC18D0029_7530                     2019
# 98  CONT_AWD_75FCMC18F0063_7530_47QTCA18D002T_4732                     2019
# 99     CONT_AWD_75FCMC18F0071_7530_GS00F090CA_4732                     2019
#
#                              awarding_sub_agency_name  \
# 0          CENTERS FOR DISEASE CONTROL AND PREVENTION
# 1          CENTERS FOR DISEASE CONTROL AND PREVENTION
# 2   OFFICE OF ASSISTANT SECRETARY FOR PREPAREDNESS...
# 3   OFFICE OF ASSISTANT SECRETARY FOR PREPAREDNESS...
# 4   OFFICE OF ASSISTANT SECRETARY FOR PREPAREDNESS...
# ..                                                ...
# 95                              INDIAN HEALTH SERVICE
# 96                              INDIAN HEALTH SERVICE
# 97         CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 98         CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 99         CENTERS FOR MEDICARE AND MEDICAID SERVICES
#
#                    awarding_office_name  \
# 0    CDC OFFICE OF ACQUISITION SERVICES
# 1    CDC OFFICE OF ACQUISITION SERVICES
# 2            OFFICE OF ACQ  MGMT POLICY
# 3            OFFICE OF ACQ  MGMT POLICY
# 4            OFFICE OF ACQ  MGMT POLICY
# ..                                  ...
# 95  GREAT PLAINS AREA INDIAN HEALTH SVC
# 96        NAVAJO AREA INDIAN HEALTH SVC
# 97   OFC OF ACQUISITION AND GRANTS MGMT
# 98   OFC OF ACQUISITION AND GRANTS MGMT
# 99   OFC OF ACQUISITION AND GRANTS MGMT
#
#                            recipient_parent_name  federal_action_obligation
# 0                                        BESTICA                        0.0
# 1                       2M RESEARCH SERVICES LLC                        0.0
# 2                       LIBRA REALTY GROUP  INC.                        0.0
# 3                         AMNEAL BIOSCIENCES LLC                        0.0
# 4                          ACT 1 GROUP  INC  THE                        0.0
# ..                                           ...                        ...
# 95          DAX SAFETY & STAFFING SOLUTIONS  LLC                        0.0
# 96  GALLUP FIRE EXTINGUISHER SALES & SERVICE INC                    -1000.5
# 97                 LANTANA CONSULTING GROUP  LLC                        0.0
# 98                       BLUE LABS ANALYTICS INC                        0.0
# 99                ACTUARIAL RESEARCH CORPORATION                        0.0
#
# [100 rows x 6 columns]

# %%
clean_data_df=pd.DataFrame(sort_data_df)
clean_data_df=clean_data_df.sort_values(["federal_action_obligation"], ascending=False) 
clean_data_df.head(30)
# Out:
#                                contract_award_unique_key  \
# 536194     CONT_AWD_HHSD200201354508C_7523_-NONE-_-NONE-
# 219473     CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 397860     CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 71141      CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 501256     CONT_AWD_HHSD200201354509C_7523_-NONE-_-NONE-
# 311693     CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 626905     CONT_AWD_HHSD200201138200C_7523_-NONE-_-NONE-
# 27294      CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 443282      CONT_AWD_HHS0001_7530_HHSM500200600003I_7530
# 561354     CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 203282     CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 585576     CONT_AWD_HHSD200201250133C_7523_-NONE-_-NONE-
# 435530     CONT_AWD_HHSD200201458152C_7523_-NONE-_-NONE-
# 189833     CONT_AWD_HHSD200201793274C_7523_-NONE-_-NONE-
# 406772     CONT_AWD_HHSD200201354509C_7523_-NONE-_-NONE-
# 566555     CONT_AWD_HHSD200201138203C_7523_-NONE-_-NONE-
# 556438     CONT_AWD_HHSD200201354509C_7523_-NONE-_-NONE-
# 517363     CONT_AWD_HHSD200201354508C_7523_-NONE-_-NONE-
# 577943     CONT_AWD_HHSD200201250135C_7523_-NONE-_-NONE-
# 514703     CONT_AWD_HHSD200201250133C_7523_-NONE-_-NONE-
# 74142      CONT_AWD_HHSD200201793274C_7523_-NONE-_-NONE-
# 79017      CONT_AWD_HHSD200201793272C_7523_-NONE-_-NONE-
# 110797     CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 586824     CONT_AWD_HHSD200201250133C_7523_-NONE-_-NONE-
# 44433      CONT_AWD_HHSO100201600030C_7505_-NONE-_-NONE-
# 36879   CONT_AWD_75N91019F00129_7529_75N91019D00024_7529
# 631304     CONT_AWD_HHSD200201142084C_7523_-NONE-_-NONE-
# 458194     CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 312288     CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 633877     CONT_AWD_HHSD200201250136C_7523_-NONE-_-NONE-
#
#         action_date_fiscal_year  \
# 536194                     2013
# 219473                     2017
# 397860                     2014
# 71141                      2018
# 501256                     2013
# 311693                     2015
# 626905                     2012
# 27294                      2019
# 443282                     2014
# 561354                     2013
# 203282                     2017
# 585576                     2012
# 435530                     2014
# 189833                     2017
# 406772                     2014
# 566555                     2012
# 556438                     2013
# 517363                     2013
# 577943                     2012
# 514703                     2013
# 74142                      2018
# 79017                      2018
# 110797                     2018
# 586824                     2012
# 44433                      2019
# 36879                      2019
# 631304                     2012
# 458194                     2014
# 312288                     2015
# 633877                     2012
#
#                                  awarding_sub_agency_name  \
# 536194         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 219473         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 397860         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 71141          CENTERS FOR DISEASE CONTROL AND PREVENTION
# 501256         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 311693         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 626905         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 27294          CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 443282         CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 561354         CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 203282         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 585576         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 435530         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 189833         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 406772         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 566555         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 556438         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 517363         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 577943         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 514703         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 74142          CENTERS FOR DISEASE CONTROL AND PREVENTION
# 79017          CENTERS FOR DISEASE CONTROL AND PREVENTION
# 110797         CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 586824         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 44433   OFFICE OF ASSISTANT SECRETARY FOR PREPAREDNESS...
# 36879                       NATIONAL INSTITUTES OF HEALTH
# 631304         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 458194         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 312288         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 633877         CENTERS FOR DISEASE CONTROL AND PREVENTION
#
#                            awarding_office_name  \
# 536194  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 219473       CDC OFFICE OF ACQUISITION SERVICES
# 397860  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 71141        CDC OFFICE OF ACQUISITION SERVICES
# 501256  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 311693  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 626905  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 27294        OFC OF ACQUISITION AND GRANTS MGMT
# 443282                          DEPT OF HHS/CMS
# 561354                          DEPT OF HHS/CMS
# 203282       CDC OFFICE OF ACQUISITION SERVICES
# 585576  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 435530  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 189833       CDC OFFICE OF ACQUISITION SERVICES
# 406772  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 566555  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 556438  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 517363  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 577943  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 514703  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 74142        CDC OFFICE OF ACQUISITION SERVICES
# 79017        CDC OFFICE OF ACQUISITION SERVICES
# 110797       OFC OF ACQUISITION AND GRANTS MGMT
# 586824  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 44433                OFFICE OF ACQ  MGMT POLICY
# 36879                                   NIH NCI
# 631304  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 458194  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 312288  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 633877  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
#
#                                recipient_parent_name  \
# 536194                                   PFIZER INC.
# 219473                             MERCK & CO.  INC.
# 397860                             MERCK & CO., INC.
# 71141                              MERCK & CO.  INC.
# 501256                             MERCK & CO., INC.
# 311693                             MERCK & CO., INC.
# 626905                             MERCK & CO., INC.
# 27294                   GENERAL DYNAMICS CORPORATION
# 443282  BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA
# 561354                  GENERAL DYNAMICS CORPORATION
# 203282                             MERCK & CO.  INC.
# 585576                             MERCK & CO., INC.
# 435530                                   PFIZER INC.
# 189833                                   PFIZER INC.
# 406772                             MERCK & CO., INC.
# 566555                                   PFIZER INC.
# 556438                             MERCK & CO., INC.
# 517363                                   PFIZER INC.
# 577943                                   PFIZER INC.
# 514703                             MERCK & CO., INC.
# 74142                                    PFIZER INC.
# 79017                            GLAXOSMITHKLINE PLC
# 110797                  GENERAL DYNAMICS CORPORATION
# 586824                             MERCK & CO., INC.
# 44433                     EMERGENT BIOSOLUTIONS INC.
# 36879                                     SAIC  INC.
# 631304                    EMERGENT BIOSOLUTIONS INC.
# 458194                             MERCK & CO., INC.
# 312288                             MERCK & CO., INC.
# 633877                                        SANOFI
#
#         federal_action_obligation
# 536194               4.717254e+08
# 219473               4.671503e+08
# 397860               4.458356e+08
# 71141                4.113393e+08
# 501256               3.802961e+08
# 311693               3.742183e+08
# 626905               3.724291e+08
# 27294                3.656774e+08
# 443282               3.455010e+08
# 561354               3.275281e+08
# 203282               3.234750e+08
# 585576               3.219691e+08
# 435530               3.116426e+08
# 189833               2.954393e+08
# 406772               2.942420e+08
# 566555               2.875528e+08
# 556438               2.862785e+08
# 517363               2.804510e+08
# 577943               2.722387e+08
# 514703               2.721819e+08
# 74142                2.689536e+08
# 79017                2.668987e+08
# 110797               2.662565e+08
# 586824               2.652864e+08
# 44433                2.609881e+08
# 36879                2.569278e+08
# 631304               2.522976e+08
# 458194               2.465408e+08
# 312288               2.388956e+08
# 633877               2.381875e+08

# %%
sort_data_df["recipient_parent_name"].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 644451    False
# 644452    False
# 644453    False
# 644454    False
# 644455    False
# Name: recipient_parent_name, Length: 644456, dtype: bool

# %%
#sort data and group by

fund_by_year=pd.DataFrame(sort_data_df.groupby(["contract_award_unique_key","action_date_fiscal_year","recipient_parent_name"])
                          ["federal_action_obligation"].sum())

fund_by_year.reset_index(inplace=True)
fund_by_year
# Out:
#                                 contract_award_unique_key  \
# 0               CONT_AWD_0001_7524_HHSF223200510007I_7524
# 1               CONT_AWD_0001_7527_HHSI241200810023I_7527
# 2               CONT_AWD_0001_7527_HHSI241200810025I_7527
# 3               CONT_AWD_0001_7527_HHSI241200810026I_7527
# 4               CONT_AWD_0001_7527_HHSI241200810378B_7527
# ...                                                   ...
# 495603  CONT_AWD_HHSS28342011T_7522_HHSS283201200002I_...
# 495604  CONT_AWD_HHSS28342011T_7522_HHSS283201200006I_...
# 495605  CONT_AWD_HHSS28342011T_7522_HHSS283201200006I_...
# 495606  CONT_AWD_HHSS28342012T_7522_HHSS283201200006I_...
# 495607       CONT_AWD_HHSTASKORDER006_7555_233020087_7555
#
#         action_date_fiscal_year              recipient_parent_name  \
# 0                          2013             DECISION PARTNERS, LLC
# 1                          2013     DOUG O'BRYAN CONTRACTING  INC.
# 2                          2013     DOUG O'BRYAN CONTRACTING  INC.
# 3                          2013  MISSOURI VALLEY RADIOLOGY  L.L.C.
# 4                          2013            RPH ON THE GO USA  INC.
# ...                         ...                                ...
# 495603                     2018            JBS INTERNATIONAL  INC.
# 495604                     2016    RESEARCH TRIANGLE INSTITUTE INC
# 495605                     2017    RESEARCH TRIANGLE INSTITUTE INC
# 495606                     2016    RESEARCH TRIANGLE INSTITUTE INC
# 495607                     2012                       WESTAT, INC.
#
#         federal_action_obligation
# 0                        -4844.52
# 1                        -2023.64
# 2                           -3.50
# 3                        -1667.33
# 4                       -12541.50
# ...                           ...
# 495603                       0.00
# 495604                 1875676.00
# 495605                 1640116.00
# 495606                 2398466.00
# 495607                       0.00
#
# [495608 rows x 4 columns]

# %%
total_fund=fund_by_year["federal_action_obligation"].sum()
print(total_fund)
# Out:
# 164773116076.61

# %%
fund_by_year.to_csv("fund_recipient_list.csv", index=False)

# %%
#creating topten list of 2016 and calculate percentage of total budget for each company

fund_2016_df=fund_by_year.loc[fund_by_year["action_date_fiscal_year"]==2016]
fund_2016_df=fund_2016_df.sort_values(["federal_action_obligation"], ascending=False)   
fund_2016_df.reset_index(inplace=True)

fund_2016_df["Total"]=19861442649.940002
fund_2016_df["Percentage"] = (fund_2016_df["federal_action_obligation"] / fund_2016_df["Total"]) * 100
fund_2016_df.head(15)
list_2016_df=pd.DataFrame(fund_2016_df)
list_2016_df.head(10)
# Out:
#     index                          contract_award_unique_key  \
# 0  271956      CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 1  286768      CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 2  272005      CONT_AWD_HHSM500201300118C_7530_-NONE-_-NONE-
# 3  105126      CONT_AWD_HHSD200201688487C_7523_-NONE-_-NONE-
# 4  463417      CONT_AWD_HHSO100201600030C_7505_-NONE-_-NONE-
# 5   80589      CONT_AWD_HHSD200201142084C_7523_-NONE-_-NONE-
# 6  274233      CONT_AWD_HHSM5002015M0028Z_7530_-NONE-_-NONE-
# 7  271733      CONT_AWD_HHSM5002012M0001Z_7530_-NONE-_-NONE-
# 8  277412  CONT_AWD_HHSM500T0003_7530_HHSM500201300014I_7530
# 9  273705      CONT_AWD_HHSM500201500246C_7530_-NONE-_-NONE-
#
#    action_date_fiscal_year                         recipient_parent_name  \
# 0                     2016                  GENERAL DYNAMICS CORPORATION
# 1                     2016                                    SAIC  INC.
# 2                     2016                               SERCO GROUP PLC
# 3                     2016                                        SANOFI
# 4                     2016                    EMERGENT BIOSOLUTIONS INC.
# 5                     2016                    EMERGENT BIOSOLUTIONS INC.
# 6                     2016  BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA
# 7                     2016   BLUE CROSS AND BLUE SHIELD OF FLORIDA  INC.
# 8                     2016            HEWLETT PACKARD ENTERPRISE COMPANY
# 9                     2016                                ACCENTURE INC.
#
#    federal_action_obligation         Total  Percentage
# 0               6.797210e+08  1.986144e+10    3.422314
# 1               4.362890e+08  1.986144e+10    2.196663
# 2               2.510530e+08  1.986144e+10    1.264022
# 3               2.012985e+08  1.986144e+10    1.013514
# 4               1.987050e+08  1.986144e+10    1.000456
# 5               1.793776e+08  1.986144e+10    0.903145
# 6               1.620792e+08  1.986144e+10    0.816049
# 7               1.548002e+08  1.986144e+10    0.779400
# 8               1.537290e+08  1.986144e+10    0.774007
# 9               1.404433e+08  1.986144e+10    0.707115

# %%
#calculating the total budget of 2016

total_fund_2016=fund_2016_df["federal_action_obligation"].sum()
print(total_fund_2016)
# Out:
# 19861442649.940002

# %%
top_ten_list_2016=list_2016_df.iloc[0:10,:]
top_ten_2016=pd.DataFrame(top_ten_list_2016)
top_ten_2016
# Out:
#     index                          contract_award_unique_key  \
# 0  271956      CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 1  286768      CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 2  272005      CONT_AWD_HHSM500201300118C_7530_-NONE-_-NONE-
# 3  105126      CONT_AWD_HHSD200201688487C_7523_-NONE-_-NONE-
# 4  463417      CONT_AWD_HHSO100201600030C_7505_-NONE-_-NONE-
# 5   80589      CONT_AWD_HHSD200201142084C_7523_-NONE-_-NONE-
# 6  274233      CONT_AWD_HHSM5002015M0028Z_7530_-NONE-_-NONE-
# 7  271733      CONT_AWD_HHSM5002012M0001Z_7530_-NONE-_-NONE-
# 8  277412  CONT_AWD_HHSM500T0003_7530_HHSM500201300014I_7530
# 9  273705      CONT_AWD_HHSM500201500246C_7530_-NONE-_-NONE-
#
#    action_date_fiscal_year                         recipient_parent_name  \
# 0                     2016                  GENERAL DYNAMICS CORPORATION
# 1                     2016                                    SAIC  INC.
# 2                     2016                               SERCO GROUP PLC
# 3                     2016                                        SANOFI
# 4                     2016                    EMERGENT BIOSOLUTIONS INC.
# 5                     2016                    EMERGENT BIOSOLUTIONS INC.
# 6                     2016  BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA
# 7                     2016   BLUE CROSS AND BLUE SHIELD OF FLORIDA  INC.
# 8                     2016            HEWLETT PACKARD ENTERPRISE COMPANY
# 9                     2016                                ACCENTURE INC.
#
#    federal_action_obligation         Total  Percentage
# 0               6.797210e+08  1.986144e+10    3.422314
# 1               4.362890e+08  1.986144e+10    2.196663
# 2               2.510530e+08  1.986144e+10    1.264022
# 3               2.012985e+08  1.986144e+10    1.013514
# 4               1.987050e+08  1.986144e+10    1.000456
# 5               1.793776e+08  1.986144e+10    0.903145
# 6               1.620792e+08  1.986144e+10    0.816049
# 7               1.548002e+08  1.986144e+10    0.779400
# 8               1.537290e+08  1.986144e+10    0.774007
# 9               1.404433e+08  1.986144e+10    0.707115

# %%
#creating topten list of 2012 and calculate percentage of total budget for each company

fund_2012_df=fund_by_year.loc[fund_by_year["action_date_fiscal_year"]==2012]
fund_2012_df=fund_2012_df.sort_values(["federal_action_obligation"], ascending=False)
fund_2012_df.reset_index(inplace=True)
fund_2012_df.head(10)

fund_2012_df["Total"]=18335069956.83
fund_2012_df["Percentage"] = (fund_2012_df["federal_action_obligation"] / fund_2012_df["Total"]) * 100
fund_2012_df.head(15)
list_2012_df=pd.DataFrame(fund_2012_df)
list_2012_df.head(10)
# Out:
#     index                          contract_award_unique_key  \
# 0   83794      CONT_AWD_HHSD200201250133C_7523_-NONE-_-NONE-
# 1   83797      CONT_AWD_HHSD200201250135C_7523_-NONE-_-NONE-
# 2   83800      CONT_AWD_HHSD200201250136C_7523_-NONE-_-NONE-
# 3  286764      CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 4   78935      CONT_AWD_HHSD200201138200C_7523_-NONE-_-NONE-
# 5   78942      CONT_AWD_HHSD200201138203C_7523_-NONE-_-NONE-
# 6   80585      CONT_AWD_HHSD200201142084C_7523_-NONE-_-NONE-
# 7   83791      CONT_AWD_HHSD200201250132C_7523_-NONE-_-NONE-
# 8  269018    CONT_AWD_HHSM500200900002U_7530_26301D0054_7530
# 9  276257  CONT_AWD_HHSM500T0001_7530_HHSM500200700001I_7530
#
#    action_date_fiscal_year         recipient_parent_name  \
# 0                     2012             MERCK & CO., INC.
# 1                     2012                   PFIZER INC.
# 2                     2012                        SANOFI
# 3                     2012                    SAIC  INC.
# 4                     2012             MERCK & CO., INC.
# 5                     2012                   PFIZER INC.
# 6                     2012    EMERGENT BIOSOLUTIONS INC.
# 7                     2012           GLAXOSMITHKLINE PLC
# 8                     2012   LOCKHEED MARTIN CORPORATION
# 9                     2012  GENERAL DYNAMICS CORPORATION
#
#    federal_action_obligation         Total  Percentage
# 0               8.900211e+08  1.833507e+10    4.854201
# 1               7.466970e+08  1.833507e+10    4.072507
# 2               5.366491e+08  1.833507e+10    2.926900
# 3               5.204117e+08  1.833507e+10    2.838340
# 4               4.855663e+08  1.833507e+10    2.648292
# 5               3.605407e+08  1.833507e+10    1.966399
# 6               3.525385e+08  1.833507e+10    1.922755
# 7               3.514480e+08  1.833507e+10    1.916807
# 8               2.046685e+08  1.833507e+10    1.116268
# 9               1.964725e+08  1.833507e+10    1.071567

# %%
#calculating the total budget of 2012

total_fund_2012=fund_2012_df["federal_action_obligation"].sum()
print(total_fund_2012)
# Out:
# 18335069956.83

# %%
top_ten_list_2012=list_2012_df.iloc[0:10,:]
top_ten_2012=pd.DataFrame(top_ten_list_2012)
top_ten_2012
# Out:
#     index                          contract_award_unique_key  \
# 0   83794      CONT_AWD_HHSD200201250133C_7523_-NONE-_-NONE-
# 1   83797      CONT_AWD_HHSD200201250135C_7523_-NONE-_-NONE-
# 2   83800      CONT_AWD_HHSD200201250136C_7523_-NONE-_-NONE-
# 3  286764      CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 4   78935      CONT_AWD_HHSD200201138200C_7523_-NONE-_-NONE-
# 5   78942      CONT_AWD_HHSD200201138203C_7523_-NONE-_-NONE-
# 6   80585      CONT_AWD_HHSD200201142084C_7523_-NONE-_-NONE-
# 7   83791      CONT_AWD_HHSD200201250132C_7523_-NONE-_-NONE-
# 8  269018    CONT_AWD_HHSM500200900002U_7530_26301D0054_7530
# 9  276257  CONT_AWD_HHSM500T0001_7530_HHSM500200700001I_7530
#
#    action_date_fiscal_year         recipient_parent_name  \
# 0                     2012             MERCK & CO., INC.
# 1                     2012                   PFIZER INC.
# 2                     2012                        SANOFI
# 3                     2012                    SAIC  INC.
# 4                     2012             MERCK & CO., INC.
# 5                     2012                   PFIZER INC.
# 6                     2012    EMERGENT BIOSOLUTIONS INC.
# 7                     2012           GLAXOSMITHKLINE PLC
# 8                     2012   LOCKHEED MARTIN CORPORATION
# 9                     2012  GENERAL DYNAMICS CORPORATION
#
#    federal_action_obligation         Total  Percentage
# 0               8.900211e+08  1.833507e+10    4.854201
# 1               7.466970e+08  1.833507e+10    4.072507
# 2               5.366491e+08  1.833507e+10    2.926900
# 3               5.204117e+08  1.833507e+10    2.838340
# 4               4.855663e+08  1.833507e+10    2.648292
# 5               3.605407e+08  1.833507e+10    1.966399
# 6               3.525385e+08  1.833507e+10    1.922755
# 7               3.514480e+08  1.833507e+10    1.916807
# 8               2.046685e+08  1.833507e+10    1.116268
# 9               1.964725e+08  1.833507e+10    1.071567

# %%
#creating topten list of 2013 and calculate percentage of total budget for each company

fund_2013_df=fund_by_year.loc[fund_by_year["action_date_fiscal_year"]==2013]
fund_2013_df=fund_2013_df.sort_values(["federal_action_obligation"], ascending=False)
fund_2013_df.reset_index(inplace=True)
fund_2013_df

fund_2013_df["Total"]=19760093354.660004
fund_2013_df["Percentage"] = (fund_2013_df["federal_action_obligation"] / fund_2013_df["Total"]) * 100
fund_2013_df.head(15)
list_2013_df=pd.DataFrame(fund_2013_df)
list_2013_df.head(10)
# Out:
#     index                      contract_award_unique_key  \
# 0   91165  CONT_AWD_HHSD200201354509C_7523_-NONE-_-NONE-
# 1   91162  CONT_AWD_HHSD200201354508C_7523_-NONE-_-NONE-
# 2  286765  CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 3  271953  CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 4   83795  CONT_AWD_HHSD200201250133C_7523_-NONE-_-NONE-
# 5   91168  CONT_AWD_HHSD200201354510C_7523_-NONE-_-NONE-
# 6   91159  CONT_AWD_HHSD200201354507C_7523_-NONE-_-NONE-
# 7   83798  CONT_AWD_HHSD200201250135C_7523_-NONE-_-NONE-
# 8   80586  CONT_AWD_HHSD200201142084C_7523_-NONE-_-NONE-
# 9   83792  CONT_AWD_HHSD200201250132C_7523_-NONE-_-NONE-
#
#    action_date_fiscal_year         recipient_parent_name  \
# 0                     2013             MERCK & CO., INC.
# 1                     2013                   PFIZER INC.
# 2                     2013                    SAIC  INC.
# 3                     2013  GENERAL DYNAMICS CORPORATION
# 4                     2013             MERCK & CO., INC.
# 5                     2013           GLAXOSMITHKLINE PLC
# 6                     2013                        SANOFI
# 7                     2013                   PFIZER INC.
# 8                     2013    EMERGENT BIOSOLUTIONS INC.
# 9                     2013           GLAXOSMITHKLINE PLC
#
#    federal_action_obligation         Total  Percentage
# 0               9.254305e+08  1.976009e+10    4.683331
# 1               6.567851e+08  1.976009e+10    3.323795
# 2               5.958887e+08  1.976009e+10    3.015617
# 3               5.322601e+08  1.976009e+10    2.693611
# 4               4.796296e+08  1.976009e+10    2.427264
# 5               3.367412e+08  1.976009e+10    1.704148
# 6               2.885536e+08  1.976009e+10    1.460285
# 7               2.302127e+08  1.976009e+10    1.165039
# 8               2.267449e+08  1.976009e+10    1.147489
# 9               2.033750e+08  1.976009e+10    1.029221

# %%
#calculating the total budget of 2013

total_fund_2013=fund_2013_df["federal_action_obligation"].sum()
print(total_fund_2013)
# Out:
# 19760093354.659996

# %%
top_ten_list_2013=list_2013_df.iloc[0:10,:]
top_ten_2013=pd.DataFrame(top_ten_list_2013)
top_ten_2013
# Out:
#     index                      contract_award_unique_key  \
# 0   91165  CONT_AWD_HHSD200201354509C_7523_-NONE-_-NONE-
# 1   91162  CONT_AWD_HHSD200201354508C_7523_-NONE-_-NONE-
# 2  286765  CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 3  271953  CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 4   83795  CONT_AWD_HHSD200201250133C_7523_-NONE-_-NONE-
# 5   91168  CONT_AWD_HHSD200201354510C_7523_-NONE-_-NONE-
# 6   91159  CONT_AWD_HHSD200201354507C_7523_-NONE-_-NONE-
# 7   83798  CONT_AWD_HHSD200201250135C_7523_-NONE-_-NONE-
# 8   80586  CONT_AWD_HHSD200201142084C_7523_-NONE-_-NONE-
# 9   83792  CONT_AWD_HHSD200201250132C_7523_-NONE-_-NONE-
#
#    action_date_fiscal_year         recipient_parent_name  \
# 0                     2013             MERCK & CO., INC.
# 1                     2013                   PFIZER INC.
# 2                     2013                    SAIC  INC.
# 3                     2013  GENERAL DYNAMICS CORPORATION
# 4                     2013             MERCK & CO., INC.
# 5                     2013           GLAXOSMITHKLINE PLC
# 6                     2013                        SANOFI
# 7                     2013                   PFIZER INC.
# 8                     2013    EMERGENT BIOSOLUTIONS INC.
# 9                     2013           GLAXOSMITHKLINE PLC
#
#    federal_action_obligation         Total  Percentage
# 0               9.254305e+08  1.976009e+10    4.683331
# 1               6.567851e+08  1.976009e+10    3.323795
# 2               5.958887e+08  1.976009e+10    3.015617
# 3               5.322601e+08  1.976009e+10    2.693611
# 4               4.796296e+08  1.976009e+10    2.427264
# 5               3.367412e+08  1.976009e+10    1.704148
# 6               2.885536e+08  1.976009e+10    1.460285
# 7               2.302127e+08  1.976009e+10    1.165039
# 8               2.267449e+08  1.976009e+10    1.147489
# 9               2.033750e+08  1.976009e+10    1.029221

# %%
#creating topten list of 2014 and calculate percentage of total budget for each company

fund_2014_df=fund_by_year.loc[fund_by_year["action_date_fiscal_year"]==2014]
fund_2014_df=fund_2014_df.sort_values(["federal_action_obligation"], ascending=False)
fund_2014_df.reset_index(inplace=True)
fund_2014_df.head(10)

fund_2014_df["Total"]=21524186077.64
fund_2014_df["Percentage"] = (fund_2014_df["federal_action_obligation"] / fund_2014_df["Total"]) * 100
fund_2014_df.head(15)
list_2014_df=pd.DataFrame(fund_2014_df)
list_2014_df.head(10)
# Out:
#     index                      contract_award_unique_key  \
# 0   96088  CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 1  271954  CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 2   96094  CONT_AWD_HHSD200201458152C_7523_-NONE-_-NONE-
# 3  286766  CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 4   91166  CONT_AWD_HHSD200201354509C_7523_-NONE-_-NONE-
# 5   55137   CONT_AWD_HHS0001_7530_HHSM500200600003I_7530
# 6   96091  CONT_AWD_HHSD200201458151C_7523_-NONE-_-NONE-
# 7   91163  CONT_AWD_HHSD200201354508C_7523_-NONE-_-NONE-
# 8  272003  CONT_AWD_HHSM500201300118C_7530_-NONE-_-NONE-
# 9   96084  CONT_AWD_HHSD200201458149C_7523_-NONE-_-NONE-
#
#    action_date_fiscal_year                         recipient_parent_name  \
# 0                     2014                             MERCK & CO., INC.
# 1                     2014                  GENERAL DYNAMICS CORPORATION
# 2                     2014                                   PFIZER INC.
# 3                     2014                                    SAIC  INC.
# 4                     2014                             MERCK & CO., INC.
# 5                     2014  BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA
# 6                     2014                           GLAXOSMITHKLINE PLC
# 7                     2014                                   PFIZER INC.
# 8                     2014                               SERCO GROUP PLC
# 9                     2014                                        SANOFI
#
#    federal_action_obligation         Total  Percentage
# 0               9.137755e+08  2.152419e+10    4.245343
# 1               6.242547e+08  2.152419e+10    2.900248
# 2               5.868276e+08  2.152419e+10    2.726364
# 3               5.394578e+08  2.152419e+10    2.506287
# 4               4.471767e+08  2.152419e+10    2.077555
# 5               3.455010e+08  2.152419e+10    1.605175
# 6               3.219371e+08  2.152419e+10    1.495699
# 7               2.685571e+08  2.152419e+10    1.247699
# 8               2.386594e+08  2.152419e+10    1.108796
# 9               2.269081e+08  2.152419e+10    1.054200

# %%
#calculating the total budget of 2014

total_fund_2014=fund_2014_df["federal_action_obligation"].sum()
print(total_fund_2014)
# Out:
# 21524186077.640003

# %%
top_ten_list_2014=list_2014_df.iloc[0:10,:]
top_ten_2014=pd.DataFrame(top_ten_list_2014)
top_ten_2014
# Out:
#     index                      contract_award_unique_key  \
# 0   96088  CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 1  271954  CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 2   96094  CONT_AWD_HHSD200201458152C_7523_-NONE-_-NONE-
# 3  286766  CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 4   91166  CONT_AWD_HHSD200201354509C_7523_-NONE-_-NONE-
# 5   55137   CONT_AWD_HHS0001_7530_HHSM500200600003I_7530
# 6   96091  CONT_AWD_HHSD200201458151C_7523_-NONE-_-NONE-
# 7   91163  CONT_AWD_HHSD200201354508C_7523_-NONE-_-NONE-
# 8  272003  CONT_AWD_HHSM500201300118C_7530_-NONE-_-NONE-
# 9   96084  CONT_AWD_HHSD200201458149C_7523_-NONE-_-NONE-
#
#    action_date_fiscal_year                         recipient_parent_name  \
# 0                     2014                             MERCK & CO., INC.
# 1                     2014                  GENERAL DYNAMICS CORPORATION
# 2                     2014                                   PFIZER INC.
# 3                     2014                                    SAIC  INC.
# 4                     2014                             MERCK & CO., INC.
# 5                     2014  BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA
# 6                     2014                           GLAXOSMITHKLINE PLC
# 7                     2014                                   PFIZER INC.
# 8                     2014                               SERCO GROUP PLC
# 9                     2014                                        SANOFI
#
#    federal_action_obligation         Total  Percentage
# 0               9.137755e+08  2.152419e+10    4.245343
# 1               6.242547e+08  2.152419e+10    2.900248
# 2               5.868276e+08  2.152419e+10    2.726364
# 3               5.394578e+08  2.152419e+10    2.506287
# 4               4.471767e+08  2.152419e+10    2.077555
# 5               3.455010e+08  2.152419e+10    1.605175
# 6               3.219371e+08  2.152419e+10    1.495699
# 7               2.685571e+08  2.152419e+10    1.247699
# 8               2.386594e+08  2.152419e+10    1.108796
# 9               2.269081e+08  2.152419e+10    1.054200

# %%
#creating topten list of 2015 and calculate percentage of total budget for each company

fund_2015_df=fund_by_year.loc[fund_by_year["action_date_fiscal_year"]==2015]
fund_2015_df=fund_2015_df.sort_values(["federal_action_obligation"], ascending=False)
fund_2015_df.reset_index(inplace=True)
fund_2015_df

fund_2015_df["Total"]=19451594748.87
fund_2015_df["Percentage"] = (fund_2015_df["federal_action_obligation"] / fund_2015_df["Total"]) * 100
fund_2015_df.head(15)
list_2015_df=pd.DataFrame(fund_2015_df)
list_2015_df.head(10)
# Out:
#     index                          contract_award_unique_key  \
# 0  271955      CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 1   96089      CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 2   96095      CONT_AWD_HHSD200201458152C_7523_-NONE-_-NONE-
# 3  286767      CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 4   96092      CONT_AWD_HHSD200201458151C_7523_-NONE-_-NONE-
# 5  277411  CONT_AWD_HHSM500T0003_7530_HHSM500201300014I_7530
# 6   96085      CONT_AWD_HHSD200201458149C_7523_-NONE-_-NONE-
# 7  272004      CONT_AWD_HHSM500201300118C_7530_-NONE-_-NONE-
# 8  273704      CONT_AWD_HHSM500201500246C_7530_-NONE-_-NONE-
# 9  100752      CONT_AWD_HHSD200201561387C_7523_-NONE-_-NONE-
#
#    action_date_fiscal_year         recipient_parent_name  \
# 0                     2015  GENERAL DYNAMICS CORPORATION
# 1                     2015             MERCK & CO., INC.
# 2                     2015                   PFIZER INC.
# 3                     2015                    SAIC  INC.
# 4                     2015           GLAXOSMITHKLINE PLC
# 5                     2015       HEWLETT-PACKARD COMPANY
# 6                     2015                        SANOFI
# 7                     2015               SERCO GROUP PLC
# 8                     2015                ACCENTURE INC.
# 9                     2015                        SANOFI
#
#    federal_action_obligation         Total  Percentage
# 0               6.199339e+08  1.945159e+10    3.187060
# 1               5.668296e+08  1.945159e+10    2.914052
# 2               4.463093e+08  1.945159e+10    2.294461
# 3               3.767760e+08  1.945159e+10    1.936993
# 4               2.801128e+08  1.945159e+10    1.440051
# 5               2.051824e+08  1.945159e+10    1.054836
# 6               2.012651e+08  1.945159e+10    1.034697
# 7               1.915214e+08  1.945159e+10    0.984605
# 8               1.552424e+08  1.945159e+10    0.798096
# 9               1.427213e+08  1.945159e+10    0.733725

# %%
#calculating the total budget of 2015

total_fund_2015=fund_2015_df["federal_action_obligation"].sum()
print(total_fund_2015)
# Out:
# 19451594748.870007

# %%
top_ten_list_2015=list_2015_df.iloc[0:10,:]
top_ten_2015=pd.DataFrame(top_ten_list_2015)
top_ten_2015
# Out:
#     index                          contract_award_unique_key  \
# 0  271955      CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 1   96089      CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 2   96095      CONT_AWD_HHSD200201458152C_7523_-NONE-_-NONE-
# 3  286767      CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 4   96092      CONT_AWD_HHSD200201458151C_7523_-NONE-_-NONE-
# 5  277411  CONT_AWD_HHSM500T0003_7530_HHSM500201300014I_7530
# 6   96085      CONT_AWD_HHSD200201458149C_7523_-NONE-_-NONE-
# 7  272004      CONT_AWD_HHSM500201300118C_7530_-NONE-_-NONE-
# 8  273704      CONT_AWD_HHSM500201500246C_7530_-NONE-_-NONE-
# 9  100752      CONT_AWD_HHSD200201561387C_7523_-NONE-_-NONE-
#
#    action_date_fiscal_year         recipient_parent_name  \
# 0                     2015  GENERAL DYNAMICS CORPORATION
# 1                     2015             MERCK & CO., INC.
# 2                     2015                   PFIZER INC.
# 3                     2015                    SAIC  INC.
# 4                     2015           GLAXOSMITHKLINE PLC
# 5                     2015       HEWLETT-PACKARD COMPANY
# 6                     2015                        SANOFI
# 7                     2015               SERCO GROUP PLC
# 8                     2015                ACCENTURE INC.
# 9                     2015                        SANOFI
#
#    federal_action_obligation         Total  Percentage
# 0               6.199339e+08  1.945159e+10    3.187060
# 1               5.668296e+08  1.945159e+10    2.914052
# 2               4.463093e+08  1.945159e+10    2.294461
# 3               3.767760e+08  1.945159e+10    1.936993
# 4               2.801128e+08  1.945159e+10    1.440051
# 5               2.051824e+08  1.945159e+10    1.054836
# 6               2.012651e+08  1.945159e+10    1.034697
# 7               1.915214e+08  1.945159e+10    0.984605
# 8               1.552424e+08  1.945159e+10    0.798096
# 9               1.427213e+08  1.945159e+10    0.733725

# %%
#creating topten list of 2017 and calculate percentage of total budget for each company

fund_2017_df=fund_by_year.loc[fund_by_year["action_date_fiscal_year"]==2017]
fund_2017_df=fund_2017_df.sort_values(["federal_action_obligation"], ascending=False)
fund_2017_df.reset_index()
fund_2017_df

fund_2017_df["Total"]=22401096082.260002
fund_2017_df["Percentage"] = (fund_2017_df["federal_action_obligation"] / fund_2017_df["Total"]) * 100
fund_2017_df.head(15)
list_2017_df=pd.DataFrame(fund_2017_df)
list_2017_df.head(10)
# Out:
#                                 contract_award_unique_key  \
# 110279      CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 271957      CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 110282      CONT_AWD_HHSD200201793274C_7523_-NONE-_-NONE-
# 286769      CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 110276      CONT_AWD_HHSD200201793272C_7523_-NONE-_-NONE-
# 272006      CONT_AWD_HHSM500201300118C_7530_-NONE-_-NONE-
# 110284      CONT_AWD_HHSD200201793275C_7523_-NONE-_-NONE-
# 110154      CONT_AWD_HHSD200201792634C_7523_-NONE-_-NONE-
# 277414  CONT_AWD_HHSM500T0003_7530_HHSM500201300014I_7530
# 437173      CONT_AWD_HHSN292201700010C_7529_-NONE-_-NONE-
#
#         action_date_fiscal_year                   recipient_parent_name  \
# 110279                     2017                       MERCK & CO.  INC.
# 271957                     2017            GENERAL DYNAMICS CORPORATION
# 110282                     2017                             PFIZER INC.
# 286769                     2017                              SAIC  INC.
# 110276                     2017                     GLAXOSMITHKLINE PLC
# 272006                     2017                         SERCO GROUP PLC
# 110284                     2017                                  SANOFI
# 110154                     2017              EMERGENT BIOSOLUTIONS INC.
# 277414                     2017                 ENTERPRISE SERVICES LLC
# 437173                     2017  THE WHITING-TURNER CONTRACTING COMPANY
#
#         federal_action_obligation         Total  Percentage
# 110279               9.570207e+08  2.240110e+10    4.272205
# 271957               6.592910e+08  2.240110e+10    2.943119
# 110282               6.096745e+08  2.240110e+10    2.721628
# 286769               5.331326e+08  2.240110e+10    2.379940
# 110276               3.520177e+08  2.240110e+10    1.571431
# 272006               3.337728e+08  2.240110e+10    1.489984
# 110284               3.136070e+08  2.240110e+10    1.399963
# 110154               2.139072e+08  2.240110e+10    0.954896
# 277414               1.868261e+08  2.240110e+10    0.834004
# 437173               1.810490e+08  2.240110e+10    0.808215

# %%
#calculating the total budget of 2018

total_fund_2017=fund_2017_df["federal_action_obligation"].sum()
print(total_fund_2017)
# Out:
# 22401096082.25999

# %%
#extrating only top 10 rowsof 2017 dataframe

top_ten_list_2017=list_2017_df.iloc[0:10,:]
top_ten_2017=pd.DataFrame(top_ten_list_2017)
top_ten_2017
# Out:
#                                 contract_award_unique_key  \
# 110279      CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 271957      CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 110282      CONT_AWD_HHSD200201793274C_7523_-NONE-_-NONE-
# 286769      CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 110276      CONT_AWD_HHSD200201793272C_7523_-NONE-_-NONE-
# 272006      CONT_AWD_HHSM500201300118C_7530_-NONE-_-NONE-
# 110284      CONT_AWD_HHSD200201793275C_7523_-NONE-_-NONE-
# 110154      CONT_AWD_HHSD200201792634C_7523_-NONE-_-NONE-
# 277414  CONT_AWD_HHSM500T0003_7530_HHSM500201300014I_7530
# 437173      CONT_AWD_HHSN292201700010C_7529_-NONE-_-NONE-
#
#         action_date_fiscal_year                   recipient_parent_name  \
# 110279                     2017                       MERCK & CO.  INC.
# 271957                     2017            GENERAL DYNAMICS CORPORATION
# 110282                     2017                             PFIZER INC.
# 286769                     2017                              SAIC  INC.
# 110276                     2017                     GLAXOSMITHKLINE PLC
# 272006                     2017                         SERCO GROUP PLC
# 110284                     2017                                  SANOFI
# 110154                     2017              EMERGENT BIOSOLUTIONS INC.
# 277414                     2017                 ENTERPRISE SERVICES LLC
# 437173                     2017  THE WHITING-TURNER CONTRACTING COMPANY
#
#         federal_action_obligation         Total  Percentage
# 110279               9.570207e+08  2.240110e+10    4.272205
# 271957               6.592910e+08  2.240110e+10    2.943119
# 110282               6.096745e+08  2.240110e+10    2.721628
# 286769               5.331326e+08  2.240110e+10    2.379940
# 110276               3.520177e+08  2.240110e+10    1.571431
# 272006               3.337728e+08  2.240110e+10    1.489984
# 110284               3.136070e+08  2.240110e+10    1.399963
# 110154               2.139072e+08  2.240110e+10    0.954896
# 277414               1.868261e+08  2.240110e+10    0.834004
# 437173               1.810490e+08  2.240110e+10    0.808215

# %%
#creating topten list of 2018 and calculate percentage of total budget for each company

fund_2018_df=fund_by_year.loc[fund_by_year["action_date_fiscal_year"]==2018]
fund_2018_df=fund_2018_df.sort_values(["federal_action_obligation"], ascending=False)
fund_2018_df.reset_index(inplace=True)
fund_2018_df

fund_2018_df["Total"]=21431638357.65
fund_2018_df["Percentage"] = (fund_2018_df["federal_action_obligation"] / fund_2018_df["Total"]) * 100
fund_2018_df.head(15)
list_2018_df=pd.DataFrame(fund_2018_df)
list_2018_df.head(10)
# Out:
#     index                          contract_award_unique_key  \
# 0  271958      CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 1  286770      CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 2  110280      CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 3  110283      CONT_AWD_HHSD200201793274C_7523_-NONE-_-NONE-
# 4  110277      CONT_AWD_HHSD200201793272C_7523_-NONE-_-NONE-
# 5  277416  CONT_AWD_HHSM500T0003_7530_HHSM500201300014I_7530
# 6   12625    CONT_AWD_75FCMC18F0045_7530_GS00Q09BGD0049_4735
# 7  110285      CONT_AWD_HHSD200201793275C_7523_-NONE-_-NONE-
# 8  152869      CONT_AWD_HHSF223201750007A_7524_-NONE-_-NONE-
# 9    1427  CONT_AWD_75A50118F33004_7505_HHSO100201300006I...
#
#    action_date_fiscal_year                   recipient_parent_name  \
# 0                     2018            GENERAL DYNAMICS CORPORATION
# 1                     2018                              SAIC  INC.
# 2                     2018                       MERCK & CO.  INC.
# 3                     2018                             PFIZER INC.
# 4                     2018                     GLAXOSMITHKLINE PLC
# 5                     2018                 ENTERPRISE SERVICES LLC
# 6                     2018                         SERCO GROUP PLC
# 7                     2018                                  SANOFI
# 8                     2018  THE INTERPUBLIC GROUP OF COMPANIES INC
# 9                     2018                              AMGEN INC.
#
#    federal_action_obligation         Total  Percentage
# 0               6.083730e+08  2.143164e+10    2.838668
# 1               5.053985e+08  2.143164e+10    2.358189
# 2               4.966425e+08  2.143164e+10    2.317333
# 3               4.192917e+08  2.143164e+10    1.956415
# 4               3.301494e+08  2.143164e+10    1.540476
# 5               2.577634e+08  2.143164e+10    1.202724
# 6               2.012226e+08  2.143164e+10    0.938905
# 7               1.636011e+08  2.143164e+10    0.763362
# 8               1.604503e+08  2.143164e+10    0.748661
# 9               1.543946e+08  2.143164e+10    0.720405

# %%
#calculating the total budget of 2018

total_fund_2018=fund_2018_df["federal_action_obligation"].sum()
print(total_fund_2018)
# Out:
# 21431638357.650005

# %%
#extrating only top 10 rowsof 2018 dataframe

top_ten_list_2018=list_2018_df.iloc[0:10,:]
top_ten_2018=pd.DataFrame(top_ten_list_2018)
top_ten_2018
# Out:
#     index                          contract_award_unique_key  \
# 0  271958      CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 1  286770      CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 2  110280      CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 3  110283      CONT_AWD_HHSD200201793274C_7523_-NONE-_-NONE-
# 4  110277      CONT_AWD_HHSD200201793272C_7523_-NONE-_-NONE-
# 5  277416  CONT_AWD_HHSM500T0003_7530_HHSM500201300014I_7530
# 6   12625    CONT_AWD_75FCMC18F0045_7530_GS00Q09BGD0049_4735
# 7  110285      CONT_AWD_HHSD200201793275C_7523_-NONE-_-NONE-
# 8  152869      CONT_AWD_HHSF223201750007A_7524_-NONE-_-NONE-
# 9    1427  CONT_AWD_75A50118F33004_7505_HHSO100201300006I...
#
#    action_date_fiscal_year                   recipient_parent_name  \
# 0                     2018            GENERAL DYNAMICS CORPORATION
# 1                     2018                              SAIC  INC.
# 2                     2018                       MERCK & CO.  INC.
# 3                     2018                             PFIZER INC.
# 4                     2018                     GLAXOSMITHKLINE PLC
# 5                     2018                 ENTERPRISE SERVICES LLC
# 6                     2018                         SERCO GROUP PLC
# 7                     2018                                  SANOFI
# 8                     2018  THE INTERPUBLIC GROUP OF COMPANIES INC
# 9                     2018                              AMGEN INC.
#
#    federal_action_obligation         Total  Percentage
# 0               6.083730e+08  2.143164e+10    2.838668
# 1               5.053985e+08  2.143164e+10    2.358189
# 2               4.966425e+08  2.143164e+10    2.317333
# 3               4.192917e+08  2.143164e+10    1.956415
# 4               3.301494e+08  2.143164e+10    1.540476
# 5               2.577634e+08  2.143164e+10    1.202724
# 6               2.012226e+08  2.143164e+10    0.938905
# 7               1.636011e+08  2.143164e+10    0.763362
# 8               1.604503e+08  2.143164e+10    0.748661
# 9               1.543946e+08  2.143164e+10    0.720405

# %%
#creating topten list of 2019 and calculate percentage of total budget for each company 

fund_2019_df=fund_by_year.loc[fund_by_year["action_date_fiscal_year"]==2019]
fund_2019_df=fund_2019_df.sort_values(["federal_action_obligation"], ascending=False)
fund_2019_df.reset_index(inplace=True)
fund_2019_df

fund_2019_df["Total"]=21431638357.65
fund_2019_df["Percentage"] = (fund_2019_df["federal_action_obligation"] / fund_2019_df["Total"]) * 100
fund_2019_df.head(15)
list_2019_df=pd.DataFrame(fund_2019_df)
list_2019_df.head(10)
# Out:
#     index                         contract_award_unique_key  \
# 0  271959     CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 1   28444  CONT_AWD_75N91019F00129_7529_75N91019D00024_7529
# 2  463420     CONT_AWD_HHSO100201600030C_7505_-NONE-_-NONE-
# 3    1644  CONT_AWD_75A50119F33001_7505_75A50118D00009_7505
# 4   12848    CONT_AWD_75FCMC19F0001_7530_75FCMC19D0070_7530
# 5   51504        CONT_AWD_75P00119C00042_7570_-NONE-_-NONE-
# 6   12626   CONT_AWD_75FCMC18F0045_7530_GS00Q09BGD0049_4735
# 7  110156     CONT_AWD_HHSD200201792634C_7523_-NONE-_-NONE-
# 8    1610        CONT_AWD_75A50119C00071_7505_-NONE-_-NONE-
# 9  463531     CONT_AWD_HHSO100201700016C_7505_-NONE-_-NONE-
#
#    action_date_fiscal_year                       recipient_parent_name  \
# 0                     2019                GENERAL DYNAMICS CORPORATION
# 1                     2019                                  SAIC  INC.
# 2                     2019                  EMERGENT BIOSOLUTIONS INC.
# 3                     2019             LOVELL GOVERNMENT SERVICES  LLC
# 4                     2019                                 LIVANTA LLC
# 5                     2019  COMPREHENSIVE HEALTH SERVICES HOLDINGS INC
# 6                     2019                             SERCO GROUP PLC
# 7                     2019                  EMERGENT BIOSOLUTIONS INC.
# 8                     2019                  EMERGENT BIOSOLUTIONS INC.
# 9                     2019               REGENERON PHARMACEUTICALS INC
#
#    federal_action_obligation         Total  Percentage
# 0               5.749075e+08  2.143164e+10    2.682518
# 1               3.520668e+08  2.143164e+10    1.642743
# 2               2.609881e+08  2.143164e+10    1.217770
# 3               2.190000e+08  2.143164e+10    1.021854
# 4               2.046229e+08  2.143164e+10    0.954770
# 5               2.021890e+08  2.143164e+10    0.943414
# 6               1.988358e+08  2.143164e+10    0.927768
# 7               1.729266e+08  2.143164e+10    0.806875
# 8               1.699880e+08  2.143164e+10    0.793164
# 9               1.546364e+08  2.143164e+10    0.721533

# %%
#calculating the total budget of 2019

total_fund_2019=fund_2019_df["federal_action_obligation"].sum()
print(total_fund_2019)
# Out:
# 22007994848.76

# %%
#extrating only top 10 rowsof 2019 dataframe

top_ten_list_2019=list_2019_df.iloc[0:10,:]
top_ten_2019=pd.DataFrame(top_ten_list_2019)
top_ten_2019
# Out:
#     index                         contract_award_unique_key  \
# 0  271959     CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 1   28444  CONT_AWD_75N91019F00129_7529_75N91019D00024_7529
# 2  463420     CONT_AWD_HHSO100201600030C_7505_-NONE-_-NONE-
# 3    1644  CONT_AWD_75A50119F33001_7505_75A50118D00009_7505
# 4   12848    CONT_AWD_75FCMC19F0001_7530_75FCMC19D0070_7530
# 5   51504        CONT_AWD_75P00119C00042_7570_-NONE-_-NONE-
# 6   12626   CONT_AWD_75FCMC18F0045_7530_GS00Q09BGD0049_4735
# 7  110156     CONT_AWD_HHSD200201792634C_7523_-NONE-_-NONE-
# 8    1610        CONT_AWD_75A50119C00071_7505_-NONE-_-NONE-
# 9  463531     CONT_AWD_HHSO100201700016C_7505_-NONE-_-NONE-
#
#    action_date_fiscal_year                       recipient_parent_name  \
# 0                     2019                GENERAL DYNAMICS CORPORATION
# 1                     2019                                  SAIC  INC.
# 2                     2019                  EMERGENT BIOSOLUTIONS INC.
# 3                     2019             LOVELL GOVERNMENT SERVICES  LLC
# 4                     2019                                 LIVANTA LLC
# 5                     2019  COMPREHENSIVE HEALTH SERVICES HOLDINGS INC
# 6                     2019                             SERCO GROUP PLC
# 7                     2019                  EMERGENT BIOSOLUTIONS INC.
# 8                     2019                  EMERGENT BIOSOLUTIONS INC.
# 9                     2019               REGENERON PHARMACEUTICALS INC
#
#    federal_action_obligation         Total  Percentage
# 0               5.749075e+08  2.143164e+10    2.682518
# 1               3.520668e+08  2.143164e+10    1.642743
# 2               2.609881e+08  2.143164e+10    1.217770
# 3               2.190000e+08  2.143164e+10    1.021854
# 4               2.046229e+08  2.143164e+10    0.954770
# 5               2.021890e+08  2.143164e+10    0.943414
# 6               1.988358e+08  2.143164e+10    0.927768
# 7               1.729266e+08  2.143164e+10    0.806875
# 8               1.699880e+08  2.143164e+10    0.793164
# 9               1.546364e+08  2.143164e+10    0.721533

# %%
#sorting dataframe to know topten

list_high_funded=sort_data_df.sort_values(["federal_action_obligation"], ascending=False)
list_high_funded.head(10)
# Out:
#                             contract_award_unique_key  \
# 536194  CONT_AWD_HHSD200201354508C_7523_-NONE-_-NONE-
# 219473  CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 397860  CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 71141   CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 501256  CONT_AWD_HHSD200201354509C_7523_-NONE-_-NONE-
# 311693  CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 626905  CONT_AWD_HHSD200201138200C_7523_-NONE-_-NONE-
# 27294   CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 443282   CONT_AWD_HHS0001_7530_HHSM500200600003I_7530
# 561354  CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
#
#         action_date_fiscal_year                    awarding_sub_agency_name  \
# 536194                     2013  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 219473                     2017  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 397860                     2014  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 71141                      2018  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 501256                     2013  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 311693                     2015  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 626905                     2012  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 27294                      2019  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 443282                     2014  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 561354                     2013  CENTERS FOR MEDICARE AND MEDICAID SERVICES
#
#                            awarding_office_name  \
# 536194  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 219473       CDC OFFICE OF ACQUISITION SERVICES
# 397860  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 71141        CDC OFFICE OF ACQUISITION SERVICES
# 501256  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 311693  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 626905  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 27294        OFC OF ACQUISITION AND GRANTS MGMT
# 443282                          DEPT OF HHS/CMS
# 561354                          DEPT OF HHS/CMS
#
#                                recipient_parent_name  \
# 536194                                   PFIZER INC.
# 219473                             MERCK & CO.  INC.
# 397860                             MERCK & CO., INC.
# 71141                              MERCK & CO.  INC.
# 501256                             MERCK & CO., INC.
# 311693                             MERCK & CO., INC.
# 626905                             MERCK & CO., INC.
# 27294                   GENERAL DYNAMICS CORPORATION
# 443282  BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA
# 561354                  GENERAL DYNAMICS CORPORATION
#
#         federal_action_obligation
# 536194               4.717254e+08
# 219473               4.671503e+08
# 397860               4.458356e+08
# 71141                4.113393e+08
# 501256               3.802961e+08
# 311693               3.742183e+08
# 626905               3.724291e+08
# 27294                3.656774e+08
# 443282               3.455010e+08
# 561354               3.275281e+08

# %%
#merging 2018 and 2019 topten
merge_12_13=pd.merge(top_ten_2012,top_ten_2013, how = "outer", on ="contract_award_unique_key")
combined_12_13_df=pd.DataFrame(merge_12_13)
combined_12_13_df
# Out:
#      index_x                          contract_award_unique_key  \
# 0    83794.0      CONT_AWD_HHSD200201250133C_7523_-NONE-_-NONE-
# 1    83797.0      CONT_AWD_HHSD200201250135C_7523_-NONE-_-NONE-
# 2    83800.0      CONT_AWD_HHSD200201250136C_7523_-NONE-_-NONE-
# 3   286764.0      CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 4    78935.0      CONT_AWD_HHSD200201138200C_7523_-NONE-_-NONE-
# 5    78942.0      CONT_AWD_HHSD200201138203C_7523_-NONE-_-NONE-
# 6    80585.0      CONT_AWD_HHSD200201142084C_7523_-NONE-_-NONE-
# 7    83791.0      CONT_AWD_HHSD200201250132C_7523_-NONE-_-NONE-
# 8   269018.0    CONT_AWD_HHSM500200900002U_7530_26301D0054_7530
# 9   276257.0  CONT_AWD_HHSM500T0001_7530_HHSM500200700001I_7530
# 10       NaN      CONT_AWD_HHSD200201354509C_7523_-NONE-_-NONE-
# 11       NaN      CONT_AWD_HHSD200201354508C_7523_-NONE-_-NONE-
# 12       NaN      CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 13       NaN      CONT_AWD_HHSD200201354510C_7523_-NONE-_-NONE-
# 14       NaN      CONT_AWD_HHSD200201354507C_7523_-NONE-_-NONE-
#
#     action_date_fiscal_year_x       recipient_parent_name_x  \
# 0                      2012.0             MERCK & CO., INC.
# 1                      2012.0                   PFIZER INC.
# 2                      2012.0                        SANOFI
# 3                      2012.0                    SAIC  INC.
# 4                      2012.0             MERCK & CO., INC.
# 5                      2012.0                   PFIZER INC.
# 6                      2012.0    EMERGENT BIOSOLUTIONS INC.
# 7                      2012.0           GLAXOSMITHKLINE PLC
# 8                      2012.0   LOCKHEED MARTIN CORPORATION
# 9                      2012.0  GENERAL DYNAMICS CORPORATION
# 10                        NaN                           NaN
# 11                        NaN                           NaN
# 12                        NaN                           NaN
# 13                        NaN                           NaN
# 14                        NaN                           NaN
#
#     federal_action_obligation_x       Total_x  Percentage_x   index_y  \
# 0                  8.900211e+08  1.833507e+10      4.854201   83795.0
# 1                  7.466970e+08  1.833507e+10      4.072507   83798.0
# 2                  5.366491e+08  1.833507e+10      2.926900       NaN
# 3                  5.204117e+08  1.833507e+10      2.838340  286765.0
# 4                  4.855663e+08  1.833507e+10      2.648292       NaN
# 5                  3.605407e+08  1.833507e+10      1.966399       NaN
# 6                  3.525385e+08  1.833507e+10      1.922755   80586.0
# 7                  3.514480e+08  1.833507e+10      1.916807   83792.0
# 8                  2.046685e+08  1.833507e+10      1.116268       NaN
# 9                  1.964725e+08  1.833507e+10      1.071567       NaN
# 10                          NaN           NaN           NaN   91165.0
# 11                          NaN           NaN           NaN   91162.0
# 12                          NaN           NaN           NaN  271953.0
# 13                          NaN           NaN           NaN   91168.0
# 14                          NaN           NaN           NaN   91159.0
#
#     action_date_fiscal_year_y       recipient_parent_name_y  \
# 0                      2013.0             MERCK & CO., INC.
# 1                      2013.0                   PFIZER INC.
# 2                         NaN                           NaN
# 3                      2013.0                    SAIC  INC.
# 4                         NaN                           NaN
# 5                         NaN                           NaN
# 6                      2013.0    EMERGENT BIOSOLUTIONS INC.
# 7                      2013.0           GLAXOSMITHKLINE PLC
# 8                         NaN                           NaN
# 9                         NaN                           NaN
# 10                     2013.0             MERCK & CO., INC.
# 11                     2013.0                   PFIZER INC.
# 12                     2013.0  GENERAL DYNAMICS CORPORATION
# 13                     2013.0           GLAXOSMITHKLINE PLC
# 14                     2013.0                        SANOFI
#
#     federal_action_obligation_y       Total_y  Percentage_y
# 0                  4.796296e+08  1.976009e+10      2.427264
# 1                  2.302127e+08  1.976009e+10      1.165039
# 2                           NaN           NaN           NaN
# 3                  5.958887e+08  1.976009e+10      3.015617
# 4                           NaN           NaN           NaN
# 5                           NaN           NaN           NaN
# 6                  2.267449e+08  1.976009e+10      1.147489
# 7                  2.033750e+08  1.976009e+10      1.029221
# 8                           NaN           NaN           NaN
# 9                           NaN           NaN           NaN
# 10                 9.254305e+08  1.976009e+10      4.683331
# 11                 6.567851e+08  1.976009e+10      3.323795
# 12                 5.322601e+08  1.976009e+10      2.693611
# 13                 3.367412e+08  1.976009e+10      1.704148
# 14                 2.885536e+08  1.976009e+10      1.460285

# %%
# Rename  _x columns to "2012" and _y columns to 2013
combined_12_13_df = combined_12_13_df.rename(columns={"action_date_fiscal_year_x":"y_2012", "recipient_parent_name_x":
                                                      "recipient_2012", "federal_action_obligation_x":"obligation_2012",
                                                     "Total_x":"total_2012", "Percentage_x":"pct_2012"})


combined_12_13_df = combined_12_13_df.rename(columns={"action_date_fiscal_year_y":"y_2013", "recipient_parent_name_y":
                                                      "recipient_2013", "federal_action_obligation_y":"obligation_2013",
                                                     "Total_y":"total_2013", "Percentage_y":"pct_2013"})
combined_12_13_df.head()
# Out:
#     index_x                      contract_award_unique_key  y_2012  \
# 0   83794.0  CONT_AWD_HHSD200201250133C_7523_-NONE-_-NONE-  2012.0
# 1   83797.0  CONT_AWD_HHSD200201250135C_7523_-NONE-_-NONE-  2012.0
# 2   83800.0  CONT_AWD_HHSD200201250136C_7523_-NONE-_-NONE-  2012.0
# 3  286764.0  CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-  2012.0
# 4   78935.0  CONT_AWD_HHSD200201138200C_7523_-NONE-_-NONE-  2012.0
#
#       recipient_2012  obligation_2012    total_2012  pct_2012   index_y  \
# 0  MERCK & CO., INC.     8.900211e+08  1.833507e+10  4.854201   83795.0
# 1        PFIZER INC.     7.466970e+08  1.833507e+10  4.072507   83798.0
# 2             SANOFI     5.366491e+08  1.833507e+10  2.926900       NaN
# 3         SAIC  INC.     5.204117e+08  1.833507e+10  2.838340  286765.0
# 4  MERCK & CO., INC.     4.855663e+08  1.833507e+10  2.648292       NaN
#
#    y_2013     recipient_2013  obligation_2013    total_2013  pct_2013
# 0  2013.0  MERCK & CO., INC.     4.796296e+08  1.976009e+10  2.427264
# 1  2013.0        PFIZER INC.     2.302127e+08  1.976009e+10  1.165039
# 2     NaN                NaN              NaN           NaN       NaN
# 3  2013.0         SAIC  INC.     5.958887e+08  1.976009e+10  3.015617
# 4     NaN                NaN              NaN           NaN       NaN

# %%
#merging 2014 and 2015 topten
merge_14_15=pd.merge(top_ten_2014,top_ten_2015, how = "outer", on ="contract_award_unique_key")
combined_14_15_df=pd.DataFrame(merge_14_15)
combined_14_15_df
# Out:
#      index_x                          contract_award_unique_key  \
# 0    96088.0      CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 1   271954.0      CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 2    96094.0      CONT_AWD_HHSD200201458152C_7523_-NONE-_-NONE-
# 3   286766.0      CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 4    91166.0      CONT_AWD_HHSD200201354509C_7523_-NONE-_-NONE-
# 5    55137.0       CONT_AWD_HHS0001_7530_HHSM500200600003I_7530
# 6    96091.0      CONT_AWD_HHSD200201458151C_7523_-NONE-_-NONE-
# 7    91163.0      CONT_AWD_HHSD200201354508C_7523_-NONE-_-NONE-
# 8   272003.0      CONT_AWD_HHSM500201300118C_7530_-NONE-_-NONE-
# 9    96084.0      CONT_AWD_HHSD200201458149C_7523_-NONE-_-NONE-
# 10       NaN  CONT_AWD_HHSM500T0003_7530_HHSM500201300014I_7530
# 11       NaN      CONT_AWD_HHSM500201500246C_7530_-NONE-_-NONE-
# 12       NaN      CONT_AWD_HHSD200201561387C_7523_-NONE-_-NONE-
#
#     action_date_fiscal_year_x                       recipient_parent_name_x  \
# 0                      2014.0                             MERCK & CO., INC.
# 1                      2014.0                  GENERAL DYNAMICS CORPORATION
# 2                      2014.0                                   PFIZER INC.
# 3                      2014.0                                    SAIC  INC.
# 4                      2014.0                             MERCK & CO., INC.
# 5                      2014.0  BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA
# 6                      2014.0                           GLAXOSMITHKLINE PLC
# 7                      2014.0                                   PFIZER INC.
# 8                      2014.0                               SERCO GROUP PLC
# 9                      2014.0                                        SANOFI
# 10                        NaN                                           NaN
# 11                        NaN                                           NaN
# 12                        NaN                                           NaN
#
#     federal_action_obligation_x       Total_x  Percentage_x   index_y  \
# 0                  9.137755e+08  2.152419e+10      4.245343   96089.0
# 1                  6.242547e+08  2.152419e+10      2.900248  271955.0
# 2                  5.868276e+08  2.152419e+10      2.726364   96095.0
# 3                  5.394578e+08  2.152419e+10      2.506287  286767.0
# 4                  4.471767e+08  2.152419e+10      2.077555       NaN
# 5                  3.455010e+08  2.152419e+10      1.605175       NaN
# 6                  3.219371e+08  2.152419e+10      1.495699   96092.0
# 7                  2.685571e+08  2.152419e+10      1.247699       NaN
# 8                  2.386594e+08  2.152419e+10      1.108796  272004.0
# 9                  2.269081e+08  2.152419e+10      1.054200   96085.0
# 10                          NaN           NaN           NaN  277411.0
# 11                          NaN           NaN           NaN  273704.0
# 12                          NaN           NaN           NaN  100752.0
#
#     action_date_fiscal_year_y       recipient_parent_name_y  \
# 0                      2015.0             MERCK & CO., INC.
# 1                      2015.0  GENERAL DYNAMICS CORPORATION
# 2                      2015.0                   PFIZER INC.
# 3                      2015.0                    SAIC  INC.
# 4                         NaN                           NaN
# 5                         NaN                           NaN
# 6                      2015.0           GLAXOSMITHKLINE PLC
# 7                         NaN                           NaN
# 8                      2015.0               SERCO GROUP PLC
# 9                      2015.0                        SANOFI
# 10                     2015.0       HEWLETT-PACKARD COMPANY
# 11                     2015.0                ACCENTURE INC.
# 12                     2015.0                        SANOFI
#
#     federal_action_obligation_y       Total_y  Percentage_y
# 0                  5.668296e+08  1.945159e+10      2.914052
# 1                  6.199339e+08  1.945159e+10      3.187060
# 2                  4.463093e+08  1.945159e+10      2.294461
# 3                  3.767760e+08  1.945159e+10      1.936993
# 4                           NaN           NaN           NaN
# 5                           NaN           NaN           NaN
# 6                  2.801128e+08  1.945159e+10      1.440051
# 7                           NaN           NaN           NaN
# 8                  1.915214e+08  1.945159e+10      0.984605
# 9                  2.012651e+08  1.945159e+10      1.034697
# 10                 2.051824e+08  1.945159e+10      1.054836
# 11                 1.552424e+08  1.945159e+10      0.798096
# 12                 1.427213e+08  1.945159e+10      0.733725

# %%
# Rename  _x columns to "2014" and _y columns to 2015
combined_14_15_df = combined_14_15_df.rename(columns={"action_date_fiscal_year_x":"y_2014", "recipient_parent_name_x":
                                                      "recipient_2014", "federal_action_obligation_x":"obligation_2014",
                                                     "Total_x":"total_2014", "Percentage_x":"pct_2014"})


combined_14_15_df = combined_14_15_df.rename(columns={"action_date_fiscal_year_y":"y_2015", "recipient_parent_name_y":
                                                      "recipient_2015", "federal_action_obligation_y":"obligation_2015",
                                                     "Total_y":"total_2015", "Percentage_y":"pct_2015"})
combined_14_15_df.head()
# Out:
#     index_x                      contract_award_unique_key  y_2014  \
# 0   96088.0  CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-  2014.0
# 1  271954.0  CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-  2014.0
# 2   96094.0  CONT_AWD_HHSD200201458152C_7523_-NONE-_-NONE-  2014.0
# 3  286766.0  CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-  2014.0
# 4   91166.0  CONT_AWD_HHSD200201354509C_7523_-NONE-_-NONE-  2014.0
#
#                  recipient_2014  obligation_2014    total_2014  pct_2014  \
# 0             MERCK & CO., INC.     9.137755e+08  2.152419e+10  4.245343
# 1  GENERAL DYNAMICS CORPORATION     6.242547e+08  2.152419e+10  2.900248
# 2                   PFIZER INC.     5.868276e+08  2.152419e+10  2.726364
# 3                    SAIC  INC.     5.394578e+08  2.152419e+10  2.506287
# 4             MERCK & CO., INC.     4.471767e+08  2.152419e+10  2.077555
#
#     index_y  y_2015                recipient_2015  obligation_2015  \
# 0   96089.0  2015.0             MERCK & CO., INC.     5.668296e+08
# 1  271955.0  2015.0  GENERAL DYNAMICS CORPORATION     6.199339e+08
# 2   96095.0  2015.0                   PFIZER INC.     4.463093e+08
# 3  286767.0  2015.0                    SAIC  INC.     3.767760e+08
# 4       NaN     NaN                           NaN              NaN
#
#      total_2015  pct_2015
# 0  1.945159e+10  2.914052
# 1  1.945159e+10  3.187060
# 2  1.945159e+10  2.294461
# 3  1.945159e+10  1.936993
# 4           NaN       NaN

# %%
#merging 2016 and 2017 topten

merge_16_17=pd.merge(top_ten_2016,top_ten_2017, how = "outer", on ="contract_award_unique_key")
combined_16_17_df=pd.DataFrame(merge_16_17)
combined_16_17_df
# Out:
#        index                          contract_award_unique_key  \
# 0   271956.0      CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 1   286768.0      CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 2   272005.0      CONT_AWD_HHSM500201300118C_7530_-NONE-_-NONE-
# 3   105126.0      CONT_AWD_HHSD200201688487C_7523_-NONE-_-NONE-
# 4   463417.0      CONT_AWD_HHSO100201600030C_7505_-NONE-_-NONE-
# 5    80589.0      CONT_AWD_HHSD200201142084C_7523_-NONE-_-NONE-
# 6   274233.0      CONT_AWD_HHSM5002015M0028Z_7530_-NONE-_-NONE-
# 7   271733.0      CONT_AWD_HHSM5002012M0001Z_7530_-NONE-_-NONE-
# 8   277412.0  CONT_AWD_HHSM500T0003_7530_HHSM500201300014I_7530
# 9   273705.0      CONT_AWD_HHSM500201500246C_7530_-NONE-_-NONE-
# 10       NaN      CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 11       NaN      CONT_AWD_HHSD200201793274C_7523_-NONE-_-NONE-
# 12       NaN      CONT_AWD_HHSD200201793272C_7523_-NONE-_-NONE-
# 13       NaN      CONT_AWD_HHSD200201793275C_7523_-NONE-_-NONE-
# 14       NaN      CONT_AWD_HHSD200201792634C_7523_-NONE-_-NONE-
# 15       NaN      CONT_AWD_HHSN292201700010C_7529_-NONE-_-NONE-
#
#     action_date_fiscal_year_x                       recipient_parent_name_x  \
# 0                      2016.0                  GENERAL DYNAMICS CORPORATION
# 1                      2016.0                                    SAIC  INC.
# 2                      2016.0                               SERCO GROUP PLC
# 3                      2016.0                                        SANOFI
# 4                      2016.0                    EMERGENT BIOSOLUTIONS INC.
# 5                      2016.0                    EMERGENT BIOSOLUTIONS INC.
# 6                      2016.0  BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA
# 7                      2016.0   BLUE CROSS AND BLUE SHIELD OF FLORIDA  INC.
# 8                      2016.0            HEWLETT PACKARD ENTERPRISE COMPANY
# 9                      2016.0                                ACCENTURE INC.
# 10                        NaN                                           NaN
# 11                        NaN                                           NaN
# 12                        NaN                                           NaN
# 13                        NaN                                           NaN
# 14                        NaN                                           NaN
# 15                        NaN                                           NaN
#
#     federal_action_obligation_x       Total_x  Percentage_x  \
# 0                  6.797210e+08  1.986144e+10      3.422314
# 1                  4.362890e+08  1.986144e+10      2.196663
# 2                  2.510530e+08  1.986144e+10      1.264022
# 3                  2.012985e+08  1.986144e+10      1.013514
# 4                  1.987050e+08  1.986144e+10      1.000456
# 5                  1.793776e+08  1.986144e+10      0.903145
# 6                  1.620792e+08  1.986144e+10      0.816049
# 7                  1.548002e+08  1.986144e+10      0.779400
# 8                  1.537290e+08  1.986144e+10      0.774007
# 9                  1.404433e+08  1.986144e+10      0.707115
# 10                          NaN           NaN           NaN
# 11                          NaN           NaN           NaN
# 12                          NaN           NaN           NaN
# 13                          NaN           NaN           NaN
# 14                          NaN           NaN           NaN
# 15                          NaN           NaN           NaN
#
#     action_date_fiscal_year_y                 recipient_parent_name_y  \
# 0                      2017.0            GENERAL DYNAMICS CORPORATION
# 1                      2017.0                              SAIC  INC.
# 2                      2017.0                         SERCO GROUP PLC
# 3                         NaN                                     NaN
# 4                         NaN                                     NaN
# 5                         NaN                                     NaN
# 6                         NaN                                     NaN
# 7                         NaN                                     NaN
# 8                      2017.0                 ENTERPRISE SERVICES LLC
# 9                         NaN                                     NaN
# 10                     2017.0                       MERCK & CO.  INC.
# 11                     2017.0                             PFIZER INC.
# 12                     2017.0                     GLAXOSMITHKLINE PLC
# 13                     2017.0                                  SANOFI
# 14                     2017.0              EMERGENT BIOSOLUTIONS INC.
# 15                     2017.0  THE WHITING-TURNER CONTRACTING COMPANY
#
#     federal_action_obligation_y       Total_y  Percentage_y
# 0                  6.592910e+08  2.240110e+10      2.943119
# 1                  5.331326e+08  2.240110e+10      2.379940
# 2                  3.337728e+08  2.240110e+10      1.489984
# 3                           NaN           NaN           NaN
# 4                           NaN           NaN           NaN
# 5                           NaN           NaN           NaN
# 6                           NaN           NaN           NaN
# 7                           NaN           NaN           NaN
# 8                  1.868261e+08  2.240110e+10      0.834004
# 9                           NaN           NaN           NaN
# 10                 9.570207e+08  2.240110e+10      4.272205
# 11                 6.096745e+08  2.240110e+10      2.721628
# 12                 3.520177e+08  2.240110e+10      1.571431
# 13                 3.136070e+08  2.240110e+10      1.399963
# 14                 2.139072e+08  2.240110e+10      0.954896
# 15                 1.810490e+08  2.240110e+10      0.808215

# %%
#renaming of columns of merged tables
combined_16_17_df = combined_16_17_df.rename(columns={"action_date_fiscal_year_x":"y_2016", "recipient_parent_name_x":
                                                      "recipient_2016", "federal_action_obligation_x":"obligation_2016",
                                                     "Total_x":"total_2016", "Percentage_x":"pct_2016"})


combined_16_17_df = combined_16_17_df.rename(columns={"action_date_fiscal_year_y":"y_2017", "recipient_parent_name_y":
                                                      "recipient_2017", "federal_action_obligation_y":"obligation_2017",
                                                     "Total_y":"total_2017", "Percentage_y":"pct_2017"})
combined_16_17_df.head()
# Out:
#       index                      contract_award_unique_key  y_2016  \
# 0  271956.0  CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-  2016.0
# 1  286768.0  CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-  2016.0
# 2  272005.0  CONT_AWD_HHSM500201300118C_7530_-NONE-_-NONE-  2016.0
# 3  105126.0  CONT_AWD_HHSD200201688487C_7523_-NONE-_-NONE-  2016.0
# 4  463417.0  CONT_AWD_HHSO100201600030C_7505_-NONE-_-NONE-  2016.0
#
#                  recipient_2016  obligation_2016    total_2016  pct_2016  \
# 0  GENERAL DYNAMICS CORPORATION     6.797210e+08  1.986144e+10  3.422314
# 1                    SAIC  INC.     4.362890e+08  1.986144e+10  2.196663
# 2               SERCO GROUP PLC     2.510530e+08  1.986144e+10  1.264022
# 3                        SANOFI     2.012985e+08  1.986144e+10  1.013514
# 4    EMERGENT BIOSOLUTIONS INC.     1.987050e+08  1.986144e+10  1.000456
#
#    y_2017                recipient_2017  obligation_2017    total_2017  \
# 0  2017.0  GENERAL DYNAMICS CORPORATION     6.592910e+08  2.240110e+10
# 1  2017.0                    SAIC  INC.     5.331326e+08  2.240110e+10
# 2  2017.0               SERCO GROUP PLC     3.337728e+08  2.240110e+10
# 3     NaN                           NaN              NaN           NaN
# 4     NaN                           NaN              NaN           NaN
#
#    pct_2017
# 0  2.943119
# 1  2.379940
# 2  1.489984
# 3       NaN
# 4       NaN

# %%
#merging 2018 and 2019 topten
merge_18_19=pd.merge(top_ten_2018,top_ten_2019, how = "outer", on ="contract_award_unique_key")
combined_18_19_df=pd.DataFrame(merge_18_19)
combined_18_19_df
# Out:
#      index_x                          contract_award_unique_key  \
# 0   271958.0      CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 1   286770.0      CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-
# 2   110280.0      CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 3   110283.0      CONT_AWD_HHSD200201793274C_7523_-NONE-_-NONE-
# 4   110277.0      CONT_AWD_HHSD200201793272C_7523_-NONE-_-NONE-
# 5   277416.0  CONT_AWD_HHSM500T0003_7530_HHSM500201300014I_7530
# 6    12625.0    CONT_AWD_75FCMC18F0045_7530_GS00Q09BGD0049_4735
# 7   110285.0      CONT_AWD_HHSD200201793275C_7523_-NONE-_-NONE-
# 8   152869.0      CONT_AWD_HHSF223201750007A_7524_-NONE-_-NONE-
# 9     1427.0  CONT_AWD_75A50118F33004_7505_HHSO100201300006I...
# 10       NaN   CONT_AWD_75N91019F00129_7529_75N91019D00024_7529
# 11       NaN      CONT_AWD_HHSO100201600030C_7505_-NONE-_-NONE-
# 12       NaN   CONT_AWD_75A50119F33001_7505_75A50118D00009_7505
# 13       NaN     CONT_AWD_75FCMC19F0001_7530_75FCMC19D0070_7530
# 14       NaN         CONT_AWD_75P00119C00042_7570_-NONE-_-NONE-
# 15       NaN      CONT_AWD_HHSD200201792634C_7523_-NONE-_-NONE-
# 16       NaN         CONT_AWD_75A50119C00071_7505_-NONE-_-NONE-
# 17       NaN      CONT_AWD_HHSO100201700016C_7505_-NONE-_-NONE-
#
#     action_date_fiscal_year_x                 recipient_parent_name_x  \
# 0                      2018.0            GENERAL DYNAMICS CORPORATION
# 1                      2018.0                              SAIC  INC.
# 2                      2018.0                       MERCK & CO.  INC.
# 3                      2018.0                             PFIZER INC.
# 4                      2018.0                     GLAXOSMITHKLINE PLC
# 5                      2018.0                 ENTERPRISE SERVICES LLC
# 6                      2018.0                         SERCO GROUP PLC
# 7                      2018.0                                  SANOFI
# 8                      2018.0  THE INTERPUBLIC GROUP OF COMPANIES INC
# 9                      2018.0                              AMGEN INC.
# 10                        NaN                                     NaN
# 11                        NaN                                     NaN
# 12                        NaN                                     NaN
# 13                        NaN                                     NaN
# 14                        NaN                                     NaN
# 15                        NaN                                     NaN
# 16                        NaN                                     NaN
# 17                        NaN                                     NaN
#
#     federal_action_obligation_x       Total_x  Percentage_x   index_y  \
# 0                  6.083730e+08  2.143164e+10      2.838668  271959.0
# 1                  5.053985e+08  2.143164e+10      2.358189       NaN
# 2                  4.966425e+08  2.143164e+10      2.317333       NaN
# 3                  4.192917e+08  2.143164e+10      1.956415       NaN
# 4                  3.301494e+08  2.143164e+10      1.540476       NaN
# 5                  2.577634e+08  2.143164e+10      1.202724       NaN
# 6                  2.012226e+08  2.143164e+10      0.938905   12626.0
# 7                  1.636011e+08  2.143164e+10      0.763362       NaN
# 8                  1.604503e+08  2.143164e+10      0.748661       NaN
# 9                  1.543946e+08  2.143164e+10      0.720405       NaN
# 10                          NaN           NaN           NaN   28444.0
# 11                          NaN           NaN           NaN  463420.0
# 12                          NaN           NaN           NaN    1644.0
# 13                          NaN           NaN           NaN   12848.0
# 14                          NaN           NaN           NaN   51504.0
# 15                          NaN           NaN           NaN  110156.0
# 16                          NaN           NaN           NaN    1610.0
# 17                          NaN           NaN           NaN  463531.0
#
#     action_date_fiscal_year_y                     recipient_parent_name_y  \
# 0                      2019.0                GENERAL DYNAMICS CORPORATION
# 1                         NaN                                         NaN
# 2                         NaN                                         NaN
# 3                         NaN                                         NaN
# 4                         NaN                                         NaN
# 5                         NaN                                         NaN
# 6                      2019.0                             SERCO GROUP PLC
# 7                         NaN                                         NaN
# 8                         NaN                                         NaN
# 9                         NaN                                         NaN
# 10                     2019.0                                  SAIC  INC.
# 11                     2019.0                  EMERGENT BIOSOLUTIONS INC.
# 12                     2019.0             LOVELL GOVERNMENT SERVICES  LLC
# 13                     2019.0                                 LIVANTA LLC
# 14                     2019.0  COMPREHENSIVE HEALTH SERVICES HOLDINGS INC
# 15                     2019.0                  EMERGENT BIOSOLUTIONS INC.
# 16                     2019.0                  EMERGENT BIOSOLUTIONS INC.
# 17                     2019.0               REGENERON PHARMACEUTICALS INC
#
#     federal_action_obligation_y       Total_y  Percentage_y
# 0                  5.749075e+08  2.143164e+10      2.682518
# 1                           NaN           NaN           NaN
# 2                           NaN           NaN           NaN
# 3                           NaN           NaN           NaN
# 4                           NaN           NaN           NaN
# 5                           NaN           NaN           NaN
# 6                  1.988358e+08  2.143164e+10      0.927768
# 7                           NaN           NaN           NaN
# 8                           NaN           NaN           NaN
# 9                           NaN           NaN           NaN
# 10                 3.520668e+08  2.143164e+10      1.642743
# 11                 2.609881e+08  2.143164e+10      1.217770
# 12                 2.190000e+08  2.143164e+10      1.021854
# 13                 2.046229e+08  2.143164e+10      0.954770
# 14                 2.021890e+08  2.143164e+10      0.943414
# 15                 1.729266e+08  2.143164e+10      0.806875
# 16                 1.699880e+08  2.143164e+10      0.793164
# 17                 1.546364e+08  2.143164e+10      0.721533

# %%
#renaming of columns of merged tables

combined_18_19_df = combined_18_19_df.rename(columns={"action_date_fiscal_year_x":"y_2018", "recipient_parent_name_x":
                                                      "recipient_2018", "federal_action_obligation_x":"obligation_2018",
                                                     "Total_x":"total_2018", "Percentage_x":"pct_2018"})


combined_18_19_df = combined_18_19_df.rename(columns={"action_date_fiscal_year_y":"y_2019", "recipient_parent_name_y":
                                                      "recipient_2019", "federal_action_obligation_y":"obligation_2019",
                                                     "Total_y":"total_2019", "Percentage_y":"pct_2019"})
combined_18_19_df.head()
# Out:
#     index_x                      contract_award_unique_key  y_2018  \
# 0  271958.0  CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-  2018.0
# 1  286770.0  CONT_AWD_HHSN261200800001E_7529_-NONE-_-NONE-  2018.0
# 2  110280.0  CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-  2018.0
# 3  110283.0  CONT_AWD_HHSD200201793274C_7523_-NONE-_-NONE-  2018.0
# 4  110277.0  CONT_AWD_HHSD200201793272C_7523_-NONE-_-NONE-  2018.0
#
#                  recipient_2018  obligation_2018    total_2018  pct_2018  \
# 0  GENERAL DYNAMICS CORPORATION     6.083730e+08  2.143164e+10  2.838668
# 1                    SAIC  INC.     5.053985e+08  2.143164e+10  2.358189
# 2             MERCK & CO.  INC.     4.966425e+08  2.143164e+10  2.317333
# 3                   PFIZER INC.     4.192917e+08  2.143164e+10  1.956415
# 4           GLAXOSMITHKLINE PLC     3.301494e+08  2.143164e+10  1.540476
#
#     index_y  y_2019                recipient_2019  obligation_2019  \
# 0  271959.0  2019.0  GENERAL DYNAMICS CORPORATION      574907474.0
# 1       NaN     NaN                           NaN              NaN
# 2       NaN     NaN                           NaN              NaN
# 3       NaN     NaN                           NaN              NaN
# 4       NaN     NaN                           NaN              NaN
#
#      total_2019  pct_2019
# 0  2.143164e+10  2.682518
# 1           NaN       NaN
# 2           NaN       NaN
# 3           NaN       NaN
# 4           NaN       NaN

# %%
#creating a dataframe

highfund_recipient_list=pd.DataFrame(list_high_funded)
highfund_recipient_list.reset_index()
highfund_recipient_list.head(10)
# Out:
#                             contract_award_unique_key  \
# 536194  CONT_AWD_HHSD200201354508C_7523_-NONE-_-NONE-
# 219473  CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 397860  CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 71141   CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 501256  CONT_AWD_HHSD200201354509C_7523_-NONE-_-NONE-
# 311693  CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 626905  CONT_AWD_HHSD200201138200C_7523_-NONE-_-NONE-
# 27294   CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 443282   CONT_AWD_HHS0001_7530_HHSM500200600003I_7530
# 561354  CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
#
#         action_date_fiscal_year                    awarding_sub_agency_name  \
# 536194                     2013  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 219473                     2017  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 397860                     2014  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 71141                      2018  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 501256                     2013  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 311693                     2015  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 626905                     2012  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 27294                      2019  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 443282                     2014  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 561354                     2013  CENTERS FOR MEDICARE AND MEDICAID SERVICES
#
#                            awarding_office_name  \
# 536194  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 219473       CDC OFFICE OF ACQUISITION SERVICES
# 397860  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 71141        CDC OFFICE OF ACQUISITION SERVICES
# 501256  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 311693  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 626905  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 27294        OFC OF ACQUISITION AND GRANTS MGMT
# 443282                          DEPT OF HHS/CMS
# 561354                          DEPT OF HHS/CMS
#
#                                recipient_parent_name  \
# 536194                                   PFIZER INC.
# 219473                             MERCK & CO.  INC.
# 397860                             MERCK & CO., INC.
# 71141                              MERCK & CO.  INC.
# 501256                             MERCK & CO., INC.
# 311693                             MERCK & CO., INC.
# 626905                             MERCK & CO., INC.
# 27294                   GENERAL DYNAMICS CORPORATION
# 443282  BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA
# 561354                  GENERAL DYNAMICS CORPORATION
#
#         federal_action_obligation
# 536194               4.717254e+08
# 219473               4.671503e+08
# 397860               4.458356e+08
# 71141                4.113393e+08
# 501256               3.802961e+08
# 311693               3.742183e+08
# 626905               3.724291e+08
# 27294                3.656774e+08
# 443282               3.455010e+08
# 561354               3.275281e+08

# %%
#extrating only ten rows of top list

top_ten_list=highfund_recipient_list.iloc[0:10,:]
top_ten_list=pd.DataFrame(top_ten_list)
top_ten_list
# Out:
#                             contract_award_unique_key  \
# 536194  CONT_AWD_HHSD200201354508C_7523_-NONE-_-NONE-
# 219473  CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 397860  CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 71141   CONT_AWD_HHSD200201793273C_7523_-NONE-_-NONE-
# 501256  CONT_AWD_HHSD200201354509C_7523_-NONE-_-NONE-
# 311693  CONT_AWD_HHSD200201458150C_7523_-NONE-_-NONE-
# 626905  CONT_AWD_HHSD200201138200C_7523_-NONE-_-NONE-
# 27294   CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
# 443282   CONT_AWD_HHS0001_7530_HHSM500200600003I_7530
# 561354  CONT_AWD_HHSM500201300103C_7530_-NONE-_-NONE-
#
#         action_date_fiscal_year                    awarding_sub_agency_name  \
# 536194                     2013  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 219473                     2017  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 397860                     2014  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 71141                      2018  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 501256                     2013  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 311693                     2015  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 626905                     2012  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 27294                      2019  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 443282                     2014  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 561354                     2013  CENTERS FOR MEDICARE AND MEDICAID SERVICES
#
#                            awarding_office_name  \
# 536194  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 219473       CDC OFFICE OF ACQUISITION SERVICES
# 397860  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 71141        CDC OFFICE OF ACQUISITION SERVICES
# 501256  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 311693  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 626905  DEPT OF HHS/CENTERS FOR DISEASE CONTROL
# 27294        OFC OF ACQUISITION AND GRANTS MGMT
# 443282                          DEPT OF HHS/CMS
# 561354                          DEPT OF HHS/CMS
#
#                                recipient_parent_name  \
# 536194                                   PFIZER INC.
# 219473                             MERCK & CO.  INC.
# 397860                             MERCK & CO., INC.
# 71141                              MERCK & CO.  INC.
# 501256                             MERCK & CO., INC.
# 311693                             MERCK & CO., INC.
# 626905                             MERCK & CO., INC.
# 27294                   GENERAL DYNAMICS CORPORATION
# 443282  BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA
# 561354                  GENERAL DYNAMICS CORPORATION
#
#         federal_action_obligation
# 536194               4.717254e+08
# 219473               4.671503e+08
# 397860               4.458356e+08
# 71141                4.113393e+08
# 501256               3.802961e+08
# 311693               3.742183e+08
# 626905               3.724291e+08
# 27294                3.656774e+08
# 443282               3.455010e+08
# 561354               3.275281e+08

# %%
#Creating a pivot table of topten companies over the 9 years period
top_list_count=pd.DataFrame(top_ten_list.groupby(["recipient_parent_name","action_date_fiscal_year","federal_action_obligation"]
                                                )["contract_award_unique_key"].count())

#top_list=top_ten_list.pivot(index = "contract_award_unique_key", columns="action_date_fiscal_year",                               
                          #  values=["federal_action_obligation","recipient_parent_name"])
#top_list.head(20)
#toplist count
top_counts=top_list_count.sort_values(["contract_award_unique_key"], ascending=False)
top_counts.head(20)
# Out:
#                                                                                                 contract_award_unique_key
# recipient_parent_name                        action_date_fiscal_year federal_action_obligation
# BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA 2014                    3.455010e+08                                       1
# GENERAL DYNAMICS CORPORATION                 2013                    3.275281e+08                                       1
#                                              2019                    3.656774e+08                                       1
# MERCK & CO.  INC.                            2017                    4.671503e+08                                       1
#                                              2018                    4.113393e+08                                       1
# MERCK & CO., INC.                            2012                    3.724291e+08                                       1
#                                              2013                    3.802961e+08                                       1
#                                              2014                    4.458356e+08                                       1
#                                              2015                    3.742183e+08                                       1
# PFIZER INC.                                  2013                    4.717254e+08                                       1

# %%
#plot=top_list.plot.barh("recipient_parent_name")

# %%
#highfund_recipient_list.get(["2012","recipient_parent_name","federal_action_obligation" ])
new = highfund_recipient_list.groupby('recipient_parent_name').sum()
new = new.sort_values(["federal_action_obligation"], ascending=False)
#new.head(10)
new["Total"]=164773116076.61002
#new.head(10)

new["Percentage"] = (new["federal_action_obligation"] / new["Total"])*100       #.map('{:.2f%}'.format)
new.head(15)
top_list_df=pd.DataFrame(new)
top_list_df.head(10)
# Out:
#                                               action_date_fiscal_year  \
# recipient_parent_name
# GENERAL DYNAMICS CORPORATION                                  2355274
# SAIC  INC.                                                    2137152
# MERCK & CO., INC.                                              434939
# PFIZER INC.                                                    495916
# GLAXOSMITHKLINE PLC                                           1188980
# SANOFI                                                        1206938
# BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA                  1149213
# EMERGENT BIOSOLUTIONS INC.                                     328715
# BOOZ ALLEN HAMILTON HOLDING CORPORATION                       3789591
# DELOITTE LLP                                                  4834320
#
#                                               federal_action_obligation  \
# recipient_parent_name
# GENERAL DYNAMICS CORPORATION                               7.280812e+09
# SAIC  INC.                                                 5.797954e+09
# MERCK & CO., INC.                                          4.808527e+09
# PFIZER INC.                                                4.423094e+09
# GLAXOSMITHKLINE PLC                                        3.361246e+09
# SANOFI                                                     3.274350e+09
# BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA               2.931020e+09
# EMERGENT BIOSOLUTIONS INC.                                 2.658780e+09
# BOOZ ALLEN HAMILTON HOLDING CORPORATION                    2.038091e+09
# DELOITTE LLP                                               1.940960e+09
#
#                                                      Total  Percentage
# recipient_parent_name
# GENERAL DYNAMICS CORPORATION                  1.647731e+11    4.418690
# SAIC  INC.                                    1.647731e+11    3.518750
# MERCK & CO., INC.                             1.647731e+11    2.918271
# PFIZER INC.                                   1.647731e+11    2.684354
# GLAXOSMITHKLINE PLC                           1.647731e+11    2.039924
# SANOFI                                        1.647731e+11    1.987187
# BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA  1.647731e+11    1.778822
# EMERGENT BIOSOLUTIONS INC.                    1.647731e+11    1.613600
# BOOZ ALLEN HAMILTON HOLDING CORPORATION       1.647731e+11    1.236907
# DELOITTE LLP                                  1.647731e+11    1.177959

# %%
total_nine_years=new["federal_action_obligation"].sum()
print(total_nine_years)
# Out:
# 164773116076.61002

# %%
#top_list=highfund_recipient_list.pivot(index = "contract_award_unique_key", columns="action_date_fiscal_year",
                              # values="federal_action_obligation")

# %%
#plot=top_list_df.plot.pie(y="federal_action_obligation", figsize=(5,5))

# %%
#extract only top ten and create dataframe

topten_list=top_list_df.iloc[0:10,:]
topten_df=pd.DataFrame(topten_list)
topten_df
# Out:
#                                               action_date_fiscal_year  \
# recipient_parent_name
# GENERAL DYNAMICS CORPORATION                                  2355274
# SAIC  INC.                                                    2137152
# MERCK & CO., INC.                                              434939
# PFIZER INC.                                                    495916
# GLAXOSMITHKLINE PLC                                           1188980
# SANOFI                                                        1206938
# BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA                  1149213
# EMERGENT BIOSOLUTIONS INC.                                     328715
# BOOZ ALLEN HAMILTON HOLDING CORPORATION                       3789591
# DELOITTE LLP                                                  4834320
#
#                                               federal_action_obligation  \
# recipient_parent_name
# GENERAL DYNAMICS CORPORATION                               7.280812e+09
# SAIC  INC.                                                 5.797954e+09
# MERCK & CO., INC.                                          4.808527e+09
# PFIZER INC.                                                4.423094e+09
# GLAXOSMITHKLINE PLC                                        3.361246e+09
# SANOFI                                                     3.274350e+09
# BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA               2.931020e+09
# EMERGENT BIOSOLUTIONS INC.                                 2.658780e+09
# BOOZ ALLEN HAMILTON HOLDING CORPORATION                    2.038091e+09
# DELOITTE LLP                                               1.940960e+09
#
#                                                      Total  Percentage
# recipient_parent_name
# GENERAL DYNAMICS CORPORATION                  1.647731e+11    4.418690
# SAIC  INC.                                    1.647731e+11    3.518750
# MERCK & CO., INC.                             1.647731e+11    2.918271
# PFIZER INC.                                   1.647731e+11    2.684354
# GLAXOSMITHKLINE PLC                           1.647731e+11    2.039924
# SANOFI                                        1.647731e+11    1.987187
# BLUE CROSS AND BLUE SHIELD OF SOUTH CAROLINA  1.647731e+11    1.778822
# EMERGENT BIOSOLUTIONS INC.                    1.647731e+11    1.613600
# BOOZ ALLEN HAMILTON HOLDING CORPORATION       1.647731e+11    1.236907
# DELOITTE LLP                                  1.647731e+11    1.177959

# %%
#plot=topten_df.plot.pie(y="federal_action_obligation", figsize=(10,10))

Company_name=["General Dynamics Corporation", "SAIC INC.", "Merck & Co.,INC.", "Pfizer INC.", 
              "Glaxosmithkline Plc", "SANOFI", "Blue Cross and Blue Shield of South Caroline", "Emergent Biosolutions INC.", 
              "Booz Allen Hamilton Holding Corporation", "Deloitte LLP"]
obligation=topten_df["federal_action_obligation"]
#explode = (0, 0.01, 0, 0, 0, 0, 0, 0, 0, 0)

plt.title("Comparision of Top Ten Companies")
# fig = plt.figure(10, figsize=(10,20))
plt.figure(10, figsize=(10,20))

colors=('skyblue', 'lightgreen', 'pink', 'c', 'gold', 'y', 'burlywood', 'coral', 'orange', 'grey')
plt.pie(obligation, colors=colors, labels=Company_name, 
        autopct="%1.1f%%", shadow=True, startangle=90, explode=(0,0,0.2,0,0,0,0,0,0,0))

plt.savefig("Images/Top_ten_companies_RT.png")
plt.show()

# %%
#topten_df.reset_index(inplace=True)
#topten_df.drop(topten_df[["action_date_fiscal_year"]], axis=1)
topten_df.drop("action_date_fiscal_year", axis=1, inplace=True)
#topten_df

#plot=topten_df.plot.barh("recipient_parent_name")

# %%
#topten_df.drop("action_date_fiscal_year", axis=1, inplace=True)
#top_list=topten_df.drop(topten_df.columns[[0,3,4]], axis=1)
#top_list=top_list.sort_values(["federal_action_obligation"], ascending=True)
top_list
#top_list=topten_df(["federal_action_obligation"]/1000000000000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-04bbe724412e> in <module>
#       2 #top_list=topten_df.drop(topten_df.columns[[0,3,4]], axis=1)
#       3 #top_list=top_list.sort_values(["federal_action_obligation"], ascending=True)
# ----> 4 top_list
#       5 #top_list=topten_df(["federal_action_obligation"]/1000000000000)
#
# NameError: name 'top_list' is not defined

# %%
top_list["total_obligation_billion"] = (top_list["federal_action_obligation"] / 1000000000)
top_list=top_list.sort_values(["federal_action_obligation"], ascending=True)
top_list

# %%
top_list=top_list["total_obligation_billion"].map('{:.2f}%'.format)
top_companies_df=pd.DataFrame(top_list)
top_companies_df

# %%
#top_list=top_list["Percentage"].map('{:.2f}%'.format)
#top_list

# %%
company = ("Deloitte LLP","Booz Allen Hamilton Holding Corporation","Emergent Biosolutions INC.",
            "Blue Cross and Blue Shield of South Caroline", 
           "SANOFI","Glaxosmithkline Plc","Pfizer INC.","Merck & Co.,INC.","SAIC INC.","General Dynamics Corporation", 
            )
x_axis = top_list.iloc[:,3]                     # ["total_obligation_billion"]

y_axis = np.arange(len(company))
#x_axis=top_list["federal_action_obligation"]
#top_list.plot.barh(x=["federal_action_obligation"], y= "Percentage", label="compay")

plt.barh(company,x_axis,)
plt.grid(True)
plt.legend()
plt.xlabel('Total obligation', fontsize=12)
plt.ylabel('Top Ten Companies', fontsize=12)
plt.xticks(x_axis, fontsize=12, rotation=30)
plt.title('Total Award Amount Each Company Received')




# ax.set_xlabel('total_obligation_billion')
# ax.set_title('Comparision of award against total budget')

plt.show()

#top_list.plot(x='Percentage', y='total_obligation_billion', kind='barh')
#plt.savefig("Images/Top_ten_companies_barh_RT.png")

# %%
#pandas_profiling.ProfileReport(topten_df)

# %%
#pandas_profiling.ProfileReport(highfund_recipient_list)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint
import json
import os

# %%
# Import the files per year
combined_contract_data = '../Resources/Annual_HSS_Data_Cleaned.csv'
df_combined_contract = pd.read_csv(combined_contract_data, low_memory=False)

# %%
# Visualize it so that the columns and values can be referenced when needed
df_combined_contract.head()
# Out:
#               contract_transaction_unique_key  \
# 0  7523_-NONE-_75D30118C01909_P00001_-NONE-_0
# 1  7523_-NONE-_75D30118C02052_P00001_-NONE-_0
# 2    7523_-NONE-_HHSD200201692404C_3_-NONE-_0
# 3    7523_-NONE-_HHSD200201692405C_3_-NONE-_0
# 4    7523_-NONE-_HHSD200201692406C_8_-NONE-_0
#
#                        contract_award_unique_key      award_id_piid  \
# 0     CONT_AWD_75D30118C01909_7523_-NONE-_-NONE-     75D30118C01909
# 1     CONT_AWD_75D30118C02052_7523_-NONE-_-NONE-     75D30118C02052
# 2  CONT_AWD_HHSD200201692404C_7523_-NONE-_-NONE-  HHSD200201692404C
# 3  CONT_AWD_HHSD200201692405C_7523_-NONE-_-NONE-  HHSD200201692405C
# 4  CONT_AWD_HHSD200201692406C_7523_-NONE-_-NONE-  HHSD200201692406C
#
#   modification_number parent_award_agency_name  federal_action_obligation  \
# 0              P00001                      NaN                        0.0
# 1              P00001                      NaN                        0.0
# 2                   3                      NaN                        0.0
# 3                   3                      NaN                        0.0
# 4                   8                      NaN                        0.0
#
#    total_dollars_obligated  action_date_fiscal_year  \
# 0                295822.88                     2019
# 1                152355.17                     2019
# 2               1308998.24                     2019
# 3                  9700.00                     2019
# 4                614109.66                     2019
#
#   period_of_performance_start_date period_of_performance_current_end_date  \
# 0              2018-09-28 00:00:00                    2019-06-14 00:00:00
# 1              2018-09-28 00:00:00                    2019-09-15 00:00:00
# 2              2018-10-01 00:00:00                    2021-09-26 00:00:00
# 3              2018-10-01 00:00:00                    2021-09-26 00:00:00
# 4              2018-10-01 00:00:00                    2021-09-26 00:00:00
#
#    ... community_developed_corporation_owned_firm federal_agency  \
# 0  ...                                          f              f
# 1  ...                                          f              f
# 2  ...                                          f              f
# 3  ...                                          f              f
# 4  ...                                          f              f
#
#   foreign_owned_and_located for_profit_organization  \
# 0                         f                       t
# 1                         f                       t
# 2                         f                       t
# 3                         f                       t
# 4                         f                       t
#
#   dot_certified_disadvantage self_certified_small_disadvantaged_business  \
# 0                          t                                           t
# 1                          t                                           t
# 2                          f                                           t
# 3                          f                                           f
# 4                          f                                           f
#
#   small_disadvantaged_business c8a_program_participant  \
# 0                            f                       t
# 1                            f                       t
# 2                            f                       t
# 3                            f                       f
# 4                            f                       f
#
#   historically_underutilized_business_zone_hubzone_firm  \
# 0                                                  t
# 1                                                  t
# 2                                                  t
# 3                                                  f
# 4                                                  f
#
#   sba_certified_8a_joint_venture
# 0                              f
# 1                              f
# 2                              f
# 3                              f
# 4                              f
#
# [5 rows x 87 columns]

# %%
# Count the information in the columns
df_combined_contract.count()
# Out:
# contract_transaction_unique_key                               725993
# contract_award_unique_key                                     725993
# award_id_piid                                                 725993
# modification_number                                           725993
# parent_award_agency_name                                      435174
# federal_action_obligation                                     725993
# total_dollars_obligated                                       218979
# action_date_fiscal_year                                       725993
# period_of_performance_start_date                              725993
# period_of_performance_current_end_date                        725992
# awarding_agency_name                                          725993
# awarding_sub_agency_name                                      725993
# awarding_office_name                                          725992
# funding_agency_name                                           725993
# funding_sub_agency_name                                       725993
# funding_office_name                                           725957
# recipient_name                                                725781
# recipient_parent_name                                         724225
# recipient_country_name                                        512628
# recipient_address_line_1                                      725451
# recipient_city_name                                           725546
# recipient_state_name                                          515060
# primary_place_of_performance_country_name                     725992
# primary_place_of_performance_city_name                        718203
# primary_place_of_performance_state_name                       718415
# award_type                                                    725993
# type_of_contract_pricing                                      721064
# award_description                                             725987
# action_type                                                   375528
# number_of_actions                                             725993
#                                                                ...
# alaskan_native_owned_corporation_or_firm                      725993
# american_indian_owned_business                                725993
# tribally_owned_business                                       725993
# veteran_owned_business                                        725993
# service_disabled_veteran_owned_business                       725993
# woman_owned_business                                          725993
# women_owned_small_business                                    725993
# economically_disadvantaged_women_owned_small_business         725993
# joint_venture_women_owned_small_business                      725993
# joint_venture_economic_disadvantaged_women_owned_small_bus    725993
# minority_owned_business                                       725993
# subcontinent_asian_asian_indian_american_owned_business       725993
# asian_pacific_american_owned_business                         725993
# black_american_owned_business                                 725993
# hispanic_american_owned_business                              725993
# native_american_owned_business                                725993
# other_minority_owned_business                                 725993
# contracting_officers_determination_of_business_size           725985
# contracting_officers_determination_of_business_size_code      725985
# emerging_small_business                                       725993
# community_developed_corporation_owned_firm                    725993
# federal_agency                                                725993
# foreign_owned_and_located                                     725993
# for_profit_organization                                       725993
# dot_certified_disadvantage                                    725993
# self_certified_small_disadvantaged_business                   725993
# small_disadvantaged_business                                  725993
# c8a_program_participant                                       725993
# historically_underutilized_business_zone_hubzone_firm         725993
# sba_certified_8a_joint_venture                                725993
# Length: 87, dtype: int64

# %%
# Keep only the desired columns for a new dataframe to study the industry/service categories
# I chose federal action obligations to isolate the flow of funds each year, 
# The descriptive column (NAICS) in order to capture industry info, 
# The women owned and minority owned to capture demographic information, 
# And forgeign owned and located will allow differentiation between US/Foreign contract awards and that column was not missing any data
industry_df = df_combined_contract[["federal_action_obligation","action_date_fiscal_year",
"naics_description","foreign_owned_and_located","woman_owned_business","minority_owned_business"]]

# %%
# Viewing the new dataframe
industry_df.head(20)
# Out:
#     federal_action_obligation  action_date_fiscal_year  \
# 0                        0.00                     2019
# 1                        0.00                     2019
# 2                        0.00                     2019
# 3                        0.00                     2019
# 4                        0.00                     2019
# 5                        0.00                     2019
# 6                        0.00                     2019
# 7                        0.00                     2019
# 8                        0.00                     2019
# 9                       -5.64                     2019
# 10                       0.00                     2019
# 11                       0.00                     2019
# 12                       0.00                     2019
# 13                       0.00                     2019
# 14                    -550.00                     2019
# 15                    -932.17                     2019
# 16                   -9154.00                     2019
# 17                       0.00                     2019
# 18                       0.00                     2019
# 19                  -31762.35                     2019
#
#                                     naics_description  \
# 0                CUSTOM COMPUTER PROGRAMMING SERVICES
# 1   ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNI...
# 2            PHARMACEUTICAL PREPARATION MANUFACTURING
# 3            PHARMACEUTICAL PREPARATION MANUFACTURING
# 4            PHARMACEUTICAL PREPARATION MANUFACTURING
# 5            PHARMACEUTICAL PREPARATION MANUFACTURING
# 6            PHARMACEUTICAL PREPARATION MANUFACTURING
# 7            PHARMACEUTICAL PREPARATION MANUFACTURING
# 8            PHARMACEUTICAL PREPARATION MANUFACTURING
# 9                    COMPUTER SYSTEMS DESIGN SERVICES
# 10  OTHER MEASURING AND CONTROLLING DEVICE MANUFAC...
# 11       OTHER BASIC INORGANIC CHEMICAL MANUFACTURING
# 12                       SATELLITE TELECOMMUNICATIONS
# 13   COPPER ROLLING, DRAWING, EXTRUDING, AND ALLOYING
# 14           PHARMACEUTICAL PREPARATION MANUFACTURING
# 15  OTHER ELECTRONIC AND PRECISION EQUIPMENT REPAI...
# 16   LABORATORY APPARATUS AND FURNITURE MANUFACTURING
# 17  ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...
# 18  ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...
# 19                            TEMPORARY HELP SERVICES
#
#    foreign_owned_and_located woman_owned_business minority_owned_business
# 0                          f                    f                       t
# 1                          f                    f                       f
# 2                          f                    t                       t
# 3                          f                    f                       f
# 4                          f                    t                       t
# 5                          f                    f                       f
# 6                          f                    f                       f
# 7                          f                    f                       t
# 8                          f                    f                       f
# 9                          f                    f                       t
# 10                         f                    f                       f
# 11                         t                    f                       f
# 12                         f                    f                       f
# 13                         f                    f                       f
# 14                         f                    f                       f
# 15                         f                    f                       f
# 16                         f                    f                       f
# 17                         f                    f                       f
# 18                         f                    f                       f
# 19                         f                    t                       t

# %%
# Renaming the columns to make more sense
industry_df = industry_df.rename(columns={"federal_action_obligation": "Dollar Amount Obligated/De-Obligated","action_date_fiscal_year": "Fiscal Year",
"naics_description": "North American Industry Classification","foreign_owned_and_located":"US or Foreign Business",
                                          "woman_owned_business": "Women Owned Business","minority_owned_business": "Minority Owned Business"})

# %%
# Viewing the new dataframe
industry_df.head()
# Out:
#    Dollar Amount Obligated/De-Obligated  Fiscal Year  \
# 0                                   0.0         2019
# 1                                   0.0         2019
# 2                                   0.0         2019
# 3                                   0.0         2019
# 4                                   0.0         2019
#
#               North American Industry Classification US or Foreign Business  \
# 0               CUSTOM COMPUTER PROGRAMMING SERVICES                      f
# 1  ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNI...                      f
# 2           PHARMACEUTICAL PREPARATION MANUFACTURING                      f
# 3           PHARMACEUTICAL PREPARATION MANUFACTURING                      f
# 4           PHARMACEUTICAL PREPARATION MANUFACTURING                      f
#
#   Women Owned Business Minority Owned Business
# 0                    f                       t
# 1                    f                       f
# 2                    t                       t
# 3                    f                       f
# 4                    t                       t

# %%
# Checking to see what the datatypes are for the dataframe column values
industry_df.dtypes
# Out:
# Dollar Amount Obligated/De-Obligated      float64
# Fiscal Year                                 int64
# North American Industry Classification     object
# US or Foreign Business                     object
# Women Owned Business                       object
# Minority Owned Business                    object
# dtype: object

# %%
# Delete rows that contain FY 2011
industry_df = industry_df.set_index("Fiscal Year")
industry_df = industry_df.drop(2011, axis=0)
industry_df.reset_index(level=0, inplace=True)
industry_df.tail()
# Out:
#         Fiscal Year  Dollar Amount Obligated/De-Obligated  \
# 644451         2012                             644387.92
# 644452         2012                                  0.00
# 644453         2012                              24694.29
# 644454         2012                             -40260.00
# 644455         2012                                  0.00
#
#                    North American Industry Classification  \
# 644451  ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...
# 644452  ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...
# 644453                   COMPUTER SYSTEMS DESIGN SERVICES
# 644454  BIOLOGICAL PRODUCT (EXCEPT DIAGNOSTIC) MANUFAC...
# 644455                    OTHER COMPUTER RELATED SERVICES
#
#        US or Foreign Business Women Owned Business Minority Owned Business
# 644451                      f                    t                       f
# 644452                      f                    t                       f
# 644453                      f                    f                       f
# 644454                      f                    f                       f
# 644455                      f                    f                       f

# %%
# Export final dataframe to CSV
industry_df.to_csv("../Resources/Industry_ContractData_Cleaned.csv", index=False)
